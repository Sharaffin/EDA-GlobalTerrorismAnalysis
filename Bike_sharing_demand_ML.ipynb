# %% [markdown]
# <a href="https://colab.research.google.com/github/Sharaffin/EDA-GlobalTerrorismAnalysis/blob/main/Bike_sharing_demand_ML.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # <b><u> Project Title : Seoul Bike Sharing Demand Prediction </u></b>

# %% [markdown]
# ## <b> Problem Description </b>
#
# ### Currently Rental bikes are introduced in many urban cities for the enhancement of mobility comfort. It is important to make the rental bike available and accessible to the public at the right time as it lessens the waiting time. Eventually, providing the city with a stable supply of rental bikes becomes a major concern. The crucial part is the prediction of bike count required at each hour for the stable supply of rental bikes.

# %% [markdown]
# ## <b> Data Description </b>
#
# ### <b> The dataset contains weather information (Temperature, Humidity, Windspeed, Visibility, Dewpoint, Solar radiation, Snowfall, Rainfall), the number of bikes rented per hour and date information.</b>
#
#
# ### <b>Attribute Information: </b>
#
# * ### Date : year-month-day
# * ### Rented Bike count - Count of bikes rented at each hour
# * ### Hour - Hour of he day
# * ### Temperature-Temperature in Celsius
# * ### Humidity - %
# * ### Windspeed - m/s
# * ### Visibility - 10m
# * ### Dew point temperature - Celsius
# * ### Solar radiation - MJ/m2
# * ### Rainfall - mm
# * ### Snowfall - cm
# * ### Seasons - Winter, Spring, Summer, Autumn
# * ### Holiday - Holiday/No holiday
# * ### Functional Day - NoFunc(Non Functional Hours), Fun(Functional hours)

# %%
# IMPORTING LIBRARIES 
import pandas as pd
import numpy as np
import seaborn as sns
from matplotlib import pyplot as plt

import warnings
warnings.filterwarnings('ignore')

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
path = '/content/drive/MyDrive/'

# %%
# READING DATASET
df = pd.read_csv(path + 'SeoulBikeData.csv', encoding= 'unicode_escape')

# %% [markdown]
# DATA CLEANING

# %%
df.head(50)
# Out:
#           Date  Rented Bike Count  Hour  Temperature(°C)  Humidity(%)  \
# 0   01/12/2017                254     0             -5.2           37
# 1   01/12/2017                204     1             -5.5           38
# 2   01/12/2017                173     2             -6.0           39
# 3   01/12/2017                107     3             -6.2           40
# 4   01/12/2017                 78     4             -6.0           36
# 5   01/12/2017                100     5             -6.4           37
# 6   01/12/2017                181     6             -6.6           35
# 7   01/12/2017                460     7             -7.4           38
# 8   01/12/2017                930     8             -7.6           37
# 9   01/12/2017                490     9             -6.5           27
# 10  01/12/2017                339    10             -3.5           24
# 11  01/12/2017                360    11             -0.5           21
# 12  01/12/2017                449    12              1.7           23
# 13  01/12/2017                451    13              2.4           25
# 14  01/12/2017                447    14              3.0           26
# 15  01/12/2017                463    15              2.1           36
# 16  01/12/2017                484    16              1.2           54
# 17  01/12/2017                555    17              0.8           58
# 18  01/12/2017                862    18              0.6           66
# 19  01/12/2017                600    19              0.0           77
# 20  01/12/2017                426    20             -0.3           79
# 21  01/12/2017                405    21             -0.8           81
# 22  01/12/2017                398    22             -0.9           83
# 23  01/12/2017                323    23             -1.3           84
# 24  02/12/2017                328     0             -1.8           87
# 25  02/12/2017                308     1             -2.2           86
# 26  02/12/2017                262     2             -2.9           86
# 27  02/12/2017                167     3             -3.5           81
# 28  02/12/2017                 89     4             -3.8           79
# 29  02/12/2017                 79     5             -4.0           79
# 30  02/12/2017                 70     6             -4.3           82
# 31  02/12/2017                146     7             -4.4           81
# 32  02/12/2017                219     8             -4.2           79
# 33  02/12/2017                328     9             -2.9           68
# 34  02/12/2017                334    10             -0.4           57
# 35  02/12/2017                388    11              1.9           49
# 36  02/12/2017                479    12              4.3           41
# 37  02/12/2017                606    13              6.0           36
# 38  02/12/2017                611    14              7.3           35
# 39  02/12/2017                589    15              7.6           41
# 40  02/12/2017                618    16              6.4           48
# 41  02/12/2017                572    17              6.0           51
# 42  02/12/2017                489    18              5.5           53
# 43  02/12/2017                385    19              5.0           52
# 44  02/12/2017                359    20              4.6           51
# 45  02/12/2017                377    21              4.1           55
# 46  02/12/2017                354    22              3.5           54
# 47  02/12/2017                366    23              4.0           56
# 48  03/12/2017                342     0              4.0           58
# 49  03/12/2017                227     1              3.9           69
#
#     Wind speed (m/s)  Visibility (10m)  Dew point temperature(°C)  \
# 0                2.2              2000                      -17.6
# 1                0.8              2000                      -17.6
# 2                1.0              2000                      -17.7
# 3                0.9              2000                      -17.6
# 4                2.3              2000                      -18.6
# 5                1.5              2000                      -18.7
# 6                1.3              2000                      -19.5
# 7                0.9              2000                      -19.3
# 8                1.1              2000                      -19.8
# 9                0.5              1928                      -22.4
# 10               1.2              1996                      -21.2
# 11               1.3              1936                      -20.2
# 12               1.4              2000                      -17.2
# 13               1.6              2000                      -15.6
# 14               2.0              2000                      -14.6
# 15               3.2              2000                      -11.4
# 16               4.2               793                       -7.0
# 17               1.6              2000                       -6.5
# 18               1.4              2000                       -5.0
# 19               1.7              2000                       -3.5
# 20               1.5              1913                       -3.5
# 21               0.8              1687                       -3.6
# 22               1.5              1380                       -3.4
# 23               1.0              1265                       -3.6
# 24               1.1               994                       -3.6
# 25               0.6               990                       -4.2
# 26               1.5              1256                       -4.9
# 27               2.2              1221                       -6.2
# 28               2.0              1167                       -6.9
# 29               1.5              1202                       -7.1
# 30               2.1              1178                       -6.9
# 31               2.5              1276                       -7.1
# 32               2.1              1436                       -7.3
# 33               1.6              1487                       -7.9
# 34               1.6              1309                       -7.8
# 35               1.8              1406                       -7.7
# 36               1.3              1666                       -7.8
# 37               1.8              1780                       -7.9
# 38               1.3              1955                       -7.1
# 39               2.3              1953                       -4.8
# 40               2.6              1945                       -3.8
# 41               2.5              1891                       -3.3
# 42               1.5              1697                       -3.3
# 43               2.3              1666                       -4.0
# 44               1.2              1585                       -4.6
# 45               1.2              1448                       -4.1
# 46               1.5              1446                       -4.9
# 47               1.0              1352                       -4.0
# 48               1.4              1296                       -3.5
# 49               1.7               485                       -1.2
#
#     Solar Radiation (MJ/m2)  Rainfall(mm)  Snowfall (cm) Seasons     Holiday  \
# 0                      0.00           0.0            0.0  Winter  No Holiday
# 1                      0.00           0.0            0.0  Winter  No Holiday
# 2                      0.00           0.0            0.0  Winter  No Holiday
# 3                      0.00           0.0            0.0  Winter  No Holiday
# 4                      0.00           0.0            0.0  Winter  No Holiday
# 5                      0.00           0.0            0.0  Winter  No Holiday
# 6                      0.00           0.0            0.0  Winter  No Holiday
# 7                      0.00           0.0            0.0  Winter  No Holiday
# 8                      0.01           0.0            0.0  Winter  No Holiday
# 9                      0.23           0.0            0.0  Winter  No Holiday
# 10                     0.65           0.0            0.0  Winter  No Holiday
# 11                     0.94           0.0            0.0  Winter  No Holiday
# 12                     1.11           0.0            0.0  Winter  No Holiday
# 13                     1.16           0.0            0.0  Winter  No Holiday
# 14                     1.01           0.0            0.0  Winter  No Holiday
# 15                     0.54           0.0            0.0  Winter  No Holiday
# 16                     0.24           0.0            0.0  Winter  No Holiday
# 17                     0.08           0.0            0.0  Winter  No Holiday
# 18                     0.00           0.0            0.0  Winter  No Holiday
# 19                     0.00           0.0            0.0  Winter  No Holiday
# 20                     0.00           0.0            0.0  Winter  No Holiday
# 21                     0.00           0.0            0.0  Winter  No Holiday
# 22                     0.00           0.0            0.0  Winter  No Holiday
# 23                     0.00           0.0            0.0  Winter  No Holiday
# 24                     0.00           0.0            0.0  Winter  No Holiday
# 25                     0.00           0.0            0.0  Winter  No Holiday
# 26                     0.00           0.0            0.0  Winter  No Holiday
# 27                     0.00           0.0            0.0  Winter  No Holiday
# 28                     0.00           0.0            0.0  Winter  No Holiday
# 29                     0.00           0.0            0.0  Winter  No Holiday
# 30                     0.00           0.0            0.0  Winter  No Holiday
# 31                     0.00           0.0            0.0  Winter  No Holiday
# 32                     0.01           0.0            0.0  Winter  No Holiday
# 33                     0.30           0.0            0.0  Winter  No Holiday
# 34                     0.80           0.0            0.0  Winter  No Holiday
# 35                     1.00           0.0            0.0  Winter  No Holiday
# 36                     1.09           0.0            0.0  Winter  No Holiday
# 37                     1.12           0.0            0.0  Winter  No Holiday
# 38                     0.99           0.0            0.0  Winter  No Holiday
# 39                     0.74           0.0            0.0  Winter  No Holiday
# 40                     0.22           0.0            0.0  Winter  No Holiday
# 41                     0.06           0.0            0.0  Winter  No Holiday
# 42                     0.00           0.0            0.0  Winter  No Holiday
# 43                     0.00           0.0            0.0  Winter  No Holiday
# 44                     0.00           0.0            0.0  Winter  No Holiday
# 45                     0.00           0.0            0.0  Winter  No Holiday
# 46                     0.00           0.0            0.0  Winter  No Holiday
# 47                     0.00           0.0            0.0  Winter  No Holiday
# 48                     0.00           0.0            0.0  Winter  No Holiday
# 49                     0.00           0.0            0.0  Winter  No Holiday
#
#    Functioning Day
# 0              Yes
# 1              Yes
# 2              Yes
# 3              Yes
# 4              Yes
# 5              Yes
# 6              Yes
# 7              Yes
# 8              Yes
# 9              Yes
# 10             Yes
# 11             Yes
# 12             Yes
# 13             Yes
# 14             Yes
# 15             Yes
# 16             Yes
# 17             Yes
# 18             Yes
# 19             Yes
# 20             Yes
# 21             Yes
# 22             Yes
# 23             Yes
# 24             Yes
# 25             Yes
# 26             Yes
# 27             Yes
# 28             Yes
# 29             Yes
# 30             Yes
# 31             Yes
# 32             Yes
# 33             Yes
# 34             Yes
# 35             Yes
# 36             Yes
# 37             Yes
# 38             Yes
# 39             Yes
# 40             Yes
# 41             Yes
# 42             Yes
# 43             Yes
# 44             Yes
# 45             Yes
# 46             Yes
# 47             Yes
# 48             Yes
# 49             Yes

# %%
df.shape
# Out:
# (8760, 14)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8760 entries, 0 to 8759
# Data columns (total 14 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Date                       8760 non-null   object
#  1   Rented Bike Count          8760 non-null   int64
#  2   Hour                       8760 non-null   int64
#  3   Temperature(°C)            8760 non-null   float64
#  4   Humidity(%)                8760 non-null   int64
#  5   Wind speed (m/s)           8760 non-null   float64
#  6   Visibility (10m)           8760 non-null   int64
#  7   Dew point temperature(°C)  8760 non-null   float64
#  8   Solar Radiation (MJ/m2)    8760 non-null   float64
#  9   Rainfall(mm)               8760 non-null   float64
#  10  Snowfall (cm)              8760 non-null   float64
#  11  Seasons                    8760 non-null   object
#  12  Holiday                    8760 non-null   object
#  13  Functioning Day            8760 non-null   object
# dtypes: float64(6), int64(4), object(4)
# memory usage: 958.2+ KB

# %%
df.describe(include = "all")
# Out:
#               Date  Rented Bike Count         Hour  Temperature(°C)  \
# count         8760        8760.000000  8760.000000      8760.000000
# unique         365                NaN          NaN              NaN
# top     01/12/2017                NaN          NaN              NaN
# freq            24                NaN          NaN              NaN
# mean           NaN         704.602055    11.500000        12.882922
# std            NaN         644.997468     6.922582        11.944825
# min            NaN           0.000000     0.000000       -17.800000
# 25%            NaN         191.000000     5.750000         3.500000
# 50%            NaN         504.500000    11.500000        13.700000
# 75%            NaN        1065.250000    17.250000        22.500000
# max            NaN        3556.000000    23.000000        39.400000
#
#         Humidity(%)  Wind speed (m/s)  Visibility (10m)  \
# count   8760.000000       8760.000000       8760.000000
# unique          NaN               NaN               NaN
# top             NaN               NaN               NaN
# freq            NaN               NaN               NaN
# mean      58.226256          1.724909       1436.825799
# std       20.362413          1.036300        608.298712
# min        0.000000          0.000000         27.000000
# 25%       42.000000          0.900000        940.000000
# 50%       57.000000          1.500000       1698.000000
# 75%       74.000000          2.300000       2000.000000
# max       98.000000          7.400000       2000.000000
#
#         Dew point temperature(°C)  Solar Radiation (MJ/m2)  Rainfall(mm)  \
# count                 8760.000000              8760.000000   8760.000000
# unique                        NaN                      NaN           NaN
# top                           NaN                      NaN           NaN
# freq                          NaN                      NaN           NaN
# mean                     4.073813                 0.569111      0.148687
# std                     13.060369                 0.868746      1.128193
# min                    -30.600000                 0.000000      0.000000
# 25%                     -4.700000                 0.000000      0.000000
# 50%                      5.100000                 0.010000      0.000000
# 75%                     14.800000                 0.930000      0.000000
# max                     27.200000                 3.520000     35.000000
#
#         Snowfall (cm) Seasons     Holiday Functioning Day
# count     8760.000000    8760        8760            8760
# unique            NaN       4           2               2
# top               NaN  Spring  No Holiday             Yes
# freq              NaN    2208        8328            8465
# mean         0.075068     NaN         NaN             NaN
# std          0.436746     NaN         NaN             NaN
# min          0.000000     NaN         NaN             NaN
# 25%          0.000000     NaN         NaN             NaN
# 50%          0.000000     NaN         NaN             NaN
# 75%          0.000000     NaN         NaN             NaN
# max          8.800000     NaN         NaN             NaN

# %%
# CHECKING NULL VALUES IN THE DATASET
df.isna().sum()
# Out:
# Date                         0
# Rented Bike Count            0
# Hour                         0
# Temperature(°C)              0
# Humidity(%)                  0
# Wind speed (m/s)             0
# Visibility (10m)             0
# Dew point temperature(°C)    0
# Solar Radiation (MJ/m2)      0
# Rainfall(mm)                 0
# Snowfall (cm)                0
# Seasons                      0
# Holiday                      0
# Functioning Day              0
# dtype: int64

# %%
df.columns
# Out:
# Index(['Date', 'Rented Bike Count', 'Hour', 'Temperature(°C)', 'Humidity(%)',
#        'Wind speed (m/s)', 'Visibility (10m)', 'Dew point temperature(°C)',
#        'Solar Radiation (MJ/m2)', 'Rainfall(mm)', 'Snowfall (cm)', 'Seasons',
#        'Holiday', 'Functioning Day'],
#       dtype='object')

# %%
# RENAMING COLUMNS NAME
df.columns = ['date', 'rented_bike_count', 'hour', 'temperature', 'humidity',
       'wind_speed', 'visibility', 'dew_point_temperature',
       'solar_radiation', 'rainfall', 'snowfall', 'seasons',
       'holiday', 'functioning_day']

# %%
# CHANGING DATE COLUMN TO DATETIME DTYPE
df["date"] = pd.to_datetime(df['date'].astype(str), format='%d/%m/%Y')

# %%
# ADDING 3 NEW COLUMN AS DAY , MONTH , YEAR
df["day"] = df["date"].dt.day
df["month"] = df["date"].dt.month
df["year"] = df["date"].dt.year

# %%
# REMOVING DATE COLUMN FROM THE DATASET
df = df.iloc[:,1:]

# %%
df.columns
# Out:
# Index(['rented_bike_count', 'hour', 'temperature', 'humidity', 'wind_speed',
#        'visibility', 'dew_point_temperature', 'solar_radiation', 'rainfall',
#        'snowfall', 'seasons', 'holiday', 'functioning_day', 'day', 'month',
#        'year'],
#       dtype='object')

# %%
# SLECTING ALL CATEGORICAL COLUMNS
df_cat = df.select_dtypes(include= 'object')

# %%
# DEFINING FUNCTION FOR BAR PLOT OF COLUMNS
def plot_bar(nue):
  plt.figure(figsize=(8,5))
  sns.barplot(x = nue, y= 'rented_bike_count' , data = df, label="Some Label", palette= "husl")
  plt.show()

# %%
# CATEGORICAL BAR PLOT TOWARDS RENTED BIKE COUNT(TRAGET VARIABLE)
for i in df_cat.columns:
  plot_bar(i)

# %%
# NUMERICAL COLUMNS BAR PLOT TOWARDS RENTED BIKE COUNT(TRAGET VARIABLE)
for i in df.describe().columns[1:]:
  plot_bar(i)

# %% [markdown]
# We are provided one year's worth of data, which includes several meteorological variables such as seasons, humidity, and so on. We can see from the above data that a big number of bikes are hired when there is a working day/no holiday, and that this occurs more frequently throughout the summer season. Bikes are being hired more frequently during the working day, regardless of the season.

# %%
# DISTRIBUTION OF FEATURES
for i in df.describe().columns:
  plt.figure(figsize = (11,6))
  df[i].hist(bins = 50)
  plt.xlabel(i)
  plt.show()

# %%
# PLOTING BOXPLOT TOWARDS RENTED BIKE COUNT(TRAGET VARIABLE)
for i in df.columns[1:]:
  plt.figure(figsize = (11,6))
  sns.boxplot(data = df,y = "rented_bike_count",x = i)
  plt.show()

# %%
df_cat.columns
# Out:
# Index(['seasons', 'holiday', 'functioning_day'], dtype='object')

# %%
# MAKING DUMMIES OF CATEGORICAL COLUMNS
dummies = pd.get_dummies(df[['seasons', 'holiday','functioning_day']], drop_first=True)

# %%
dummies
# Out:
#       seasons_Spring  seasons_Summer  seasons_Winter  holiday_No Holiday  \
# 0                  0               0               1                   1
# 1                  0               0               1                   1
# 2                  0               0               1                   1
# 3                  0               0               1                   1
# 4                  0               0               1                   1
# ...              ...             ...             ...                 ...
# 8755               0               0               0                   1
# 8756               0               0               0                   1
# 8757               0               0               0                   1
# 8758               0               0               0                   1
# 8759               0               0               0                   1
#
#       functioning_day_Yes
# 0                       1
# 1                       1
# 2                       1
# 3                       1
# 4                       1
# ...                   ...
# 8755                    1
# 8756                    1
# 8757                    1
# 8758                    1
# 8759                    1
#
# [8760 rows x 5 columns]

# %%
# MERGING THE DUMMIES DATASET TO THE MAIN DATASET AS NEW_DF
new_df = pd.concat([df, dummies], axis =1)

# %%
new_df.T
# Out:
#                              0           1           2           3     \
# rented_bike_count             254         204         173         107
# hour                            0           1           2           3
# temperature                  -5.2        -5.5        -6.0        -6.2
# humidity                       37          38          39          40
# wind_speed                    2.2         0.8         1.0         0.9
# visibility                   2000        2000        2000        2000
# dew_point_temperature       -17.6       -17.6       -17.7       -17.6
# solar_radiation               0.0         0.0         0.0         0.0
# rainfall                      0.0         0.0         0.0         0.0
# snowfall                      0.0         0.0         0.0         0.0
# seasons                    Winter      Winter      Winter      Winter
# holiday                No Holiday  No Holiday  No Holiday  No Holiday
# functioning_day               Yes         Yes         Yes         Yes
# day                             1           1           1           1
# month                          12          12          12          12
# year                         2017        2017        2017        2017
# seasons_Spring                  0           0           0           0
# seasons_Summer                  0           0           0           0
# seasons_Winter                  1           1           1           1
# holiday_No Holiday              1           1           1           1
# functioning_day_Yes             1           1           1           1
#
#                              4           5           6           7     \
# rented_bike_count              78         100         181         460
# hour                            4           5           6           7
# temperature                  -6.0        -6.4        -6.6        -7.4
# humidity                       36          37          35          38
# wind_speed                    2.3         1.5         1.3         0.9
# visibility                   2000        2000        2000        2000
# dew_point_temperature       -18.6       -18.7       -19.5       -19.3
# solar_radiation               0.0         0.0         0.0         0.0
# rainfall                      0.0         0.0         0.0         0.0
# snowfall                      0.0         0.0         0.0         0.0
# seasons                    Winter      Winter      Winter      Winter
# holiday                No Holiday  No Holiday  No Holiday  No Holiday
# functioning_day               Yes         Yes         Yes         Yes
# day                             1           1           1           1
# month                          12          12          12          12
# year                         2017        2017        2017        2017
# seasons_Spring                  0           0           0           0
# seasons_Summer                  0           0           0           0
# seasons_Winter                  1           1           1           1
# holiday_No Holiday              1           1           1           1
# functioning_day_Yes             1           1           1           1
#
#                              8           9     ...        8750        8751  \
# rented_bike_count             930         490  ...         761         768
# hour                            8           9  ...          14          15
# temperature                  -7.6        -6.5  ...         7.8         7.0
# humidity                       37          27  ...          20          20
# wind_speed                    1.1         0.5  ...         2.2         3.3
# visibility                   2000        1928  ...        2000        1994
# dew_point_temperature       -19.8       -22.4  ...       -13.8       -14.4
# solar_radiation              0.01        0.23  ...        1.67        1.21
# rainfall                      0.0         0.0  ...         0.0         0.0
# snowfall                      0.0         0.0  ...         0.0         0.0
# seasons                    Winter      Winter  ...      Autumn      Autumn
# holiday                No Holiday  No Holiday  ...  No Holiday  No Holiday
# functioning_day               Yes         Yes  ...         Yes         Yes
# day                             1           1  ...          30          30
# month                          12          12  ...          11          11
# year                         2017        2017  ...        2018        2018
# seasons_Spring                  0           0  ...           0           0
# seasons_Summer                  0           0  ...           0           0
# seasons_Winter                  1           1  ...           0           0
# holiday_No Holiday              1           1  ...           1           1
# functioning_day_Yes             1           1  ...           1           1
#
#                              8752        8753        8754        8755  \
# rented_bike_count             837        1047        1384        1003
# hour                           16          17          18          19
# temperature                   7.2         6.0         4.7         4.2
# humidity                       23          29          34          34
# wind_speed                    1.5         2.1         1.9         2.6
# visibility                   1945        1877        1661        1894
# dew_point_temperature       -12.6       -10.7        -9.8       -10.3
# solar_radiation              0.72        0.23         0.0         0.0
# rainfall                      0.0         0.0         0.0         0.0
# snowfall                      0.0         0.0         0.0         0.0
# seasons                    Autumn      Autumn      Autumn      Autumn
# holiday                No Holiday  No Holiday  No Holiday  No Holiday
# functioning_day               Yes         Yes         Yes         Yes
# day                            30          30          30          30
# month                          11          11          11          11
# year                         2018        2018        2018        2018
# seasons_Spring                  0           0           0           0
# seasons_Summer                  0           0           0           0
# seasons_Winter                  0           0           0           0
# holiday_No Holiday              1           1           1           1
# functioning_day_Yes             1           1           1           1
#
#                              8756        8757        8758        8759
# rented_bike_count             764         694         712         584
# hour                           20          21          22          23
# temperature                   3.4         2.6         2.1         1.9
# humidity                       37          39          41          43
# wind_speed                    2.3         0.3         1.0         1.3
# visibility                   2000        1968        1859        1909
# dew_point_temperature        -9.9        -9.9        -9.8        -9.3
# solar_radiation               0.0         0.0         0.0         0.0
# rainfall                      0.0         0.0         0.0         0.0
# snowfall                      0.0         0.0         0.0         0.0
# seasons                    Autumn      Autumn      Autumn      Autumn
# holiday                No Holiday  No Holiday  No Holiday  No Holiday
# functioning_day               Yes         Yes         Yes         Yes
# day                            30          30          30          30
# month                          11          11          11          11
# year                         2018        2018        2018        2018
# seasons_Spring                  0           0           0           0
# seasons_Summer                  0           0           0           0
# seasons_Winter                  0           0           0           0
# holiday_No Holiday              1           1           1           1
# functioning_day_Yes             1           1           1           1
#
# [21 rows x 8760 columns]

# %%
df_cat.columns
# Out:
# Index(['seasons', 'holiday', 'functioning_day'], dtype='object')

# %%
# DROPING USELESS FEATURES FROM THE DATASET
new_df.drop(['dew_point_temperature', 'seasons', 'holiday', 'functioning_day'], axis=1, inplace=True)

# %%
new_df.columns
# Out:
# Index(['rented_bike_count', 'hour', 'temperature', 'humidity', 'wind_speed',
#        'visibility', 'solar_radiation', 'rainfall', 'snowfall', 'day', 'month',
#        'year', 'seasons_Spring', 'seasons_Summer', 'seasons_Winter',
#        'holiday_No Holiday', 'functioning_day_Yes'],
#       dtype='object')

# %%
# RENAMING COLUMNS 
new_df.columns = ['rented_bike_count', 'hour', 'temperature', 'humidity', 'wind_speed',
       'visibility', 'solar_radiation', 'rainfall', 'snowfall', 'day', 'month',
       'year', 'seasons_Spring', 'seasons_Summer', 'seasons_Winter',
       'holiday', 'function_day']

# %%
# INDEPENDENT VARIBLES
X = new_df.iloc[:,1:]

# %%
# DEPENDED VARIBLE(TRAGET VARIBLE)
Y = new_df["rented_bike_count"]

# %%
# IMPORTING ML ALGORITHM FOR THE MODEL

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression,Lasso,Ridge


# SPLITTING THE X AND Y INTO X_TRAIN , X_TEST , Y_TRAIN , Y_TEST
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.25, random_state = 5)

# %% [markdown]
# LINEAR REGRESSION

# %%
# TRAINING THE MODEl
reg = LinearRegression()
reg.fit(X_train, Y_train)
# Out:
# LinearRegression()

# %%
# INTERCEPT AND COFFIENT 
reg.intercept_ , reg.coef_
# Out:
# (1345705.617822332,
#  array([ 2.70207808e+01,  2.68026164e+01, -8.68211625e+00,  2.08811341e+01,
#          6.31780845e-03, -8.95325103e+01, -5.68074528e+01,  3.62253725e+01,
#         -1.57130550e+00, -5.47507590e+01, -6.66695302e+02, -4.71220691e+02,
#         -3.06028559e+02, -8.70699131e+02,  1.17113530e+02,  9.07156536e+02]))

# %%
# PREDICTING X_TEST
y_pred=reg.predict(X_test)

# %%
# IMPOERTING SKLEARN METRICS FOR EVALUTING THE MODDEL SCORES
from sklearn.metrics import r2_score,mean_squared_error

# %%
# R-SQUARED
r2_score(Y_test, y_pred)
# Out:
# 0.5573770262170219

# %%
# MODEL FITIING ON TEST DATASET
reg.score(X_test, Y_test)
# Out:
# 0.5573770262170219

# %%
# MODEL FITTING ON TRAIN DATASET
reg.score(X_train, Y_train)
# Out:
# 0.5518544224178705

# %%
# ADJUSTED R-SQURED , MEAN SQUARED ERROR, ROOT MEAN SQUARED ERROR
print("Adjusted R2 : ",1-(1-r2_score((Y_test), (y_pred)))*((X_test.shape[0]-1)/(X_test.shape[0]-X_test.shape[1]-1)))
MSE  = mean_squared_error(Y_test, y_pred)
print("MSE :" , MSE)
RMSE = np.sqrt(MSE)
print("RMSE :" ,RMSE)
# Out:
# Adjusted R2 :  0.554117952318942
# MSE : 181118.6145432901
# RMSE : 425.5803267813141

# %% [markdown]
# LASSO REGRESSION

# %%
# IMPORTING ML ALGORITHM FOR THE MODEL AND GRIDSEARCH CV
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import Lasso

# %%
# PERFORMING HYPERPARAMETER TUNNING AND FITTING THE TRAIN DATASET 
rf_grid = GridSearchCV(Lasso(),
                       param_grid = {"alpha" : [1.1,0.001]},
                       cv = 5, verbose=2, scoring='roc_auc')

rf_grid.fit(X_train,Y_train)
# Out:
# Fitting 5 folds for each of 2 candidates, totalling 10 fits
# [CV] END ..........................................alpha=1.1; total time=   0.0s
# [CV] END ..........................................alpha=1.1; total time=   0.0s
# [CV] END ..........................................alpha=1.1; total time=   0.0s
# [CV] END ..........................................alpha=1.1; total time=   0.0s
# [CV] END ..........................................alpha=1.1; total time=   0.0s
# [CV] END ........................................alpha=0.001; total time=   0.1s
# [CV] END ........................................alpha=0.001; total time=   0.1s
# [CV] END ........................................alpha=0.001; total time=   0.1s
# [CV] END ........................................alpha=0.001; total time=   0.1s
# [CV] END ........................................alpha=0.001; total time=   0.1s
# GridSearchCV(cv=5, estimator=Lasso(), param_grid={'alpha': [1.1, 0.001]},
#              scoring='roc_auc', verbose=2)

# %%
# BEST HYPERPARAMETER
rf_grid.best_params_
# Out:
# {'alpha': 1.1}

# %%
# FITTING THE MODEL WITH BEST HYPERPARAMETER
lasso = Lasso(alpha=1.1)
lasso.fit(X_train, Y_train)
# Out:
# Lasso(alpha=1.1)

# %%
# COFFICENT
lasso.coef_
# Out:
# array([ 2.73304847e+01,  2.59275070e+01, -8.41645631e+00,  1.77838359e+01,
#         1.01449087e-02, -8.15877296e+01, -5.72252304e+01,  2.70629336e+01,
#        -1.33847758e+00,  1.20573844e+00, -5.07888443e+01, -1.12582700e+02,
#        -1.06986163e+02, -3.68740392e+02,  8.88997620e+01,  8.58483975e+02])

# %%
# INTERCEPT
lasso.intercept_
# Out:
# 102287.63487918161

# %%
# PRECDICTING X_TEST
y_pred = lasso.predict(X_test)

# %%
# R_SQUARED
r2_score (Y_test, y_pred)
# Out:
# 0.5589945870750749

# %%
#  MODEL FITIING ON TEST DATASET
lasso.score(X_test, Y_test)
# Out:
# 0.5589945870750749

# %%
# MODEL FITIING ON TRAIN DATASET
lasso.score(X_train, Y_train)
# Out:
# 0.547331619947321

# %%
# ADJUSTED R-SQURED , MEAN SQUARED ERROR, ROOT MEAN SQUARED ERROR
print("Adjusted R2 : ",1-(1-r2_score((Y_test), (y_pred)))*((X_test.shape[0]-1)/(X_test.shape[0]-X_test.shape[1]-1)))
MSE  = mean_squared_error(Y_test, y_pred)
print("MSE :" , MSE)
RMSE = np.sqrt(MSE)
print("RMSE :" ,RMSE)
# Out:
# Adjusted R2 :  0.5557474234272153
# MSE : 180456.71853042376
# RMSE : 424.8019756668085

# %%
# PLOTTING FIRST 50 Y_TEST AND Y_PRED
plt.figure(figsize=(15,10))
plt.plot(np.array(Y_test[:50]), color = "orange")
plt.plot(y_pred[:50], color = "red")
plt.title("Lasso")
plt.legend(["Predicted","Actual"])
plt.show()

# %% [markdown]
# RIDGE REGRESSION

# %%
# PERFORMING HYPERPARAMETER TUNNING AND FITTING THE TRAIN DATASET 
rf_grid = GridSearchCV(Ridge(),
                       param_grid = {"alpha" : [0,0.0000000001]},
                       cv = 5, verbose=2, scoring='roc_auc')

rf_grid.fit(X_train,Y_train)
# Out:
# Fitting 5 folds for each of 2 candidates, totalling 10 fits
# [CV] END ............................................alpha=0; total time=   0.0s
# [CV] END ............................................alpha=0; total time=   0.0s
# [CV] END ............................................alpha=0; total time=   0.0s
# [CV] END ............................................alpha=0; total time=   0.0s
# [CV] END ............................................alpha=0; total time=   0.0s
# [CV] END ........................................alpha=1e-10; total time=   0.0s
# [CV] END ........................................alpha=1e-10; total time=   0.0s
# [CV] END ........................................alpha=1e-10; total time=   0.0s
# [CV] END ........................................alpha=1e-10; total time=   0.0s
# [CV] END ........................................alpha=1e-10; total time=   0.0s
# GridSearchCV(cv=5, estimator=Ridge(), param_grid={'alpha': [0, 1e-10]},
#              scoring='roc_auc', verbose=2)

# %%
# BEST HYPERPARAMETER
rf_grid.best_params_
# Out:
# {'alpha': 0}

# %%
# FITTING THE MODEL WITH BEST HYPERPARAMETER
ridge = Ridge(alpha=0)
ridge.fit(X_train,Y_train)
# Out:
# Ridge(alpha=0)

# %%
# PREDICTING X_TEST
y_pred = ridge.predict(X_test)

# %%
# COFFICIENT
ridge.coef_
# Out:
# array([ 2.70207808e+01,  2.68026164e+01, -8.68211625e+00,  2.08811341e+01,
#         6.31780845e-03, -8.95325103e+01, -5.68074528e+01,  3.62253725e+01,
#        -1.57130550e+00, -5.47507590e+01, -6.66695302e+02, -4.71220691e+02,
#        -3.06028559e+02, -8.70699131e+02,  1.17113530e+02,  9.07156536e+02])

# %%
# INTERCEPT
ridge.intercept_
# Out:
# 1345705.6178226885

# %%
#  MODEL FITIING ON TEST DATASET
ridge.score(X_test, Y_test)
# Out:
# 0.5573770262170249

# %%
#  MODEL FITIING ON TRAIN DATASET
ridge.score(X_train, Y_train)
# Out:
# 0.551854422417872

# %%
# R_SQUARED
r2_score(Y_test, y_pred )
# Out:
# 0.5573770262170249

# %%
# ADJUSTED R-SQURED , MEAN SQUARED ERROR, ROOT MEAN SQUARED ERROR
print("Adjusted R2 : ",1-(1-r2_score((Y_test), (y_pred)))*((X_test.shape[0]-1)/(X_test.shape[0]-X_test.shape[1]-1)))
MSE  = mean_squared_error(Y_test, y_pred)
print("MSE :" , MSE)
RMSE = np.sqrt(MSE)
print("RMSE :" ,RMSE)
# Out:
# Adjusted R2 :  0.554117952318945
# MSE : 181118.61454328892
# RMSE : 425.5803267813127

# %%
# PLOTTING FIRST 50 Y_TEST AND Y_PRED
plt.figure(figsize=(15,10))
plt.plot(np.array(Y_test[:50]), color = "orange")
plt.plot(y_pred[:50], color = "red")
plt.title("Ridge")
plt.legend(["Predicted","Actual"])
plt.show()

# %% [markdown]
# ELASTIC NET

# %%
# IMPORTING ELASTIC NET
from sklearn.linear_model import ElasticNet

# %%
# PERFORMING HYPERPARAMETER TUNNING AND FITTING THE TRAIN DATASET 
rf_grid = GridSearchCV(ElasticNet(),
                       param_grid = {"alpha" : [0,1] , 'l1_ratio' : [0.99, 0.999]},
                       cv = 5, verbose=2, scoring='roc_auc')

rf_grid.fit(X_train,Y_train)
# Out:
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# [CV] END .............................alpha=0, l1_ratio=0.99; total time=   0.1s
# [CV] END .............................alpha=0, l1_ratio=0.99; total time=   0.1s
# [CV] END .............................alpha=0, l1_ratio=0.99; total time=   0.1s
# [CV] END .............................alpha=0, l1_ratio=0.99; total time=   0.1s
# [CV] END .............................alpha=0, l1_ratio=0.99; total time=   0.1s
# [CV] END ............................alpha=0, l1_ratio=0.999; total time=   0.1s
# [CV] END ............................alpha=0, l1_ratio=0.999; total time=   0.1s
# [CV] END ............................alpha=0, l1_ratio=0.999; total time=   0.1s
# [CV] END ............................alpha=0, l1_ratio=0.999; total time=   0.1s
# [CV] END ............................alpha=0, l1_ratio=0.999; total time=   0.1s
# [CV] END .............................alpha=1, l1_ratio=0.99; total time=   0.0s
# [CV] END .............................alpha=1, l1_ratio=0.99; total time=   0.0s
# [CV] END .............................alpha=1, l1_ratio=0.99; total time=   0.0s
# [CV] END .............................alpha=1, l1_ratio=0.99; total time=   0.0s
# [CV] END .............................alpha=1, l1_ratio=0.99; total time=   0.0s
# [CV] END ............................alpha=1, l1_ratio=0.999; total time=   0.0s
# [CV] END ............................alpha=1, l1_ratio=0.999; total time=   0.0s
# [CV] END ............................alpha=1, l1_ratio=0.999; total time=   0.0s
# [CV] END ............................alpha=1, l1_ratio=0.999; total time=   0.0s
# [CV] END ............................alpha=1, l1_ratio=0.999; total time=   0.0s
# GridSearchCV(cv=5, estimator=ElasticNet(),
#              param_grid={'alpha': [0, 1], 'l1_ratio': [0.99, 0.999]},
#              scoring='roc_auc', verbose=2)

# %%
# BEST HYPER PARAMETER
rf_grid.best_params_
# Out:
# {'alpha': 0, 'l1_ratio': 0.99}

# %%
# USING BEST HYPER PARAMENTER OM THE MODEL
eln = ElasticNet(alpha= 0, l1_ratio= 0.99)

# %%
# FITTING TRAIN DATA SET TO THE MODEL
eln.fit(X_train, Y_train)
# Out:
# ElasticNet(alpha=0, l1_ratio=0.99)

# %%
# PREDICTING X_TEST
y_pred = eln.predict(X_test)

# %%
# R_SQUARED
r2_score(Y_test, y_pred)
# Out:
# 0.5573770262171962

# %%
#  MODEL FITIING ON TEST DATASET
eln.score(X_test, Y_test)
# Out:
# 0.5573770262171962

# %%
#  MODEL FITIING ON TRAIN DATASET
eln.score(X_train, Y_train)
# Out:
# 0.5518544224178756

# %%
# ADJUSTED R-SQURED , MEAN SQUARED ERROR, ROOT MEAN SQUARED ERROR
print("Adjusted R2 : ",1-(1-r2_score((Y_test), (y_pred)))*((X_test.shape[0]-1)/(X_test.shape[0]-X_test.shape[1]-1)))
MSE  = mean_squared_error(Y_test, y_pred)
print("MSE :" , MSE)
RMSE = np.sqrt(MSE)
print("RMSE :" ,RMSE)
# Out:
# Adjusted R2 :  0.5541179523191175
# MSE : 181118.6145432188
# RMSE : 425.5803267812303

# %%
# PLOTTING FIRST 50 Y_TEST AND Y_PRED
plt.figure(figsize=(15,10))
plt.plot(np.array(Y_test[:50]), color = "orange")
plt.plot(y_pred[:50], color = "red")
plt.title("ElasticNet")
plt.legend(["Predicted","Actual"])
plt.show()

# %% [markdown]
# DECISION TREE

# %%
# IMPOERTING DESISION TREE REGRESSOR
from sklearn.tree import DecisionTreeRegressor

# %%
# PERFORMING HYPERPARAMETER TUNNING AND FITTING THE TRAIN DATASET 
rf_grid = GridSearchCV(DecisionTreeRegressor(),
                       param_grid = {'max_depth' :[ i for i in range(8,11)], 'min_samples_split' :[ i for i in range(8,11)], 'min_samples_leaf': [i for i in range(6,11)]},
                       cv = 5, verbose=2, scoring='roc_auc')

rf_grid.fit(X_train,Y_train)
# Out:
# Fitting 5 folds for each of 45 candidates, totalling 225 fits
# [CV] END max_depth=8, min_samples_leaf=6, min_samples_split=8; total time=   0.0s
# [CV] END max_depth=8, min_samples_leaf=6, min_samples_split=8; total time=   0.0s
# [CV] END max_depth=8, min_samples_leaf=6, min_samples_split=8; total time=   0.0s
# [CV] END max_depth=8, min_samples_leaf=6, min_samples_split=8; total time=   0.0s
# [CV] END max_depth=8, min_samples_leaf=6, min_samples_split=8; total time=   0.0s
# [CV] END max_depth=8, min_samples_leaf=6, min_samples_split=9; total time=   0.0s
# [CV] END max_depth=8, min_samples_leaf=6, min_samples_split=9; total time=   0.0s
# [CV] END max_depth=8, min_samples_leaf=6, min_samples_split=9; total time=   0.0s
# [CV] END max_depth=8, min_samples_leaf=6, min_samples_split=9; total time=   0.0s
# [CV] END max_depth=8, min_samples_leaf=6, min_samples_split=9; total time=   0.0s
# [CV] END max_depth=8, min_samples_leaf=6, min_samples_split=10; total time=   0.0s
# [CV] END max_depth=8, min_samples_leaf=6, min_samples_split=10; total time=   0.0s
# [CV] END max_depth=8, min_samples_leaf=6, min_samples_split=10; total time=   0.0s
# [CV] END max_depth=8, min_samples_leaf=6, min_samples_split=10; total time=   0.0s
# [CV] END max_depth=8, min_samples_leaf=6, min_samples_split=10; total time=   0.0s
# [CV] END max_depth=8, min_samples_leaf=7, min_samples_split=8; total time=   0.0s
# [CV] END max_depth=8, min_samples_leaf=7, min_samples_split=8; total time=   0.0s
# [CV] END max_depth=8, min_samples_leaf=7, min_samples_split=8; total time=   0.0s
# [CV] END max_depth=8, min_samples_leaf=7, min_samples_split=8; total time=   0.0s
# [CV] END max_depth=8, min_samples_leaf=7, min_samples_split=8; total time=   0.0s
# [CV] END max_depth=8, min_samples_leaf=7, min_samples_split=9; total time=   0.0s
# [CV] END max_depth=8, min_samples_leaf=7, min_samples_split=9; total time=   0.0s
# [CV] END max_depth=8, min_samples_leaf=7, min_samples_split=9; total time=   0.0s
# [CV] END max_depth=8, min_samples_leaf=7, min_samples_split=9; total time=   0.0s
# [CV] END max_depth=8, min_samples_leaf=7, min_samples_split=9; total time=   0.0s
# [CV] END max_depth=8, min_samples_leaf=7, min_samples_split=10; total time=   0.0s
# [CV] END max_depth=8, min_samples_leaf=7, min_samples_split=10; total time=   0.0s
# [CV] END max_depth=8, min_samples_leaf=7, min_samples_split=10; total time=   0.0s
# [CV] END max_depth=8, min_samples_leaf=7, min_samples_split=10; total time=   0.0s
# [CV] END max_depth=8, min_samples_leaf=7, min_samples_split=10; total time=   0.0s
# [CV] END max_depth=8, min_samples_leaf=8, min_samples_split=8; total time=   0.0s
# [CV] END max_depth=8, min_samples_leaf=8, min_samples_split=8; total time=   0.0s
# [CV] END max_depth=8, min_samples_leaf=8, min_samples_split=8; total time=   0.0s
# [CV] END max_depth=8, min_samples_leaf=8, min_samples_split=8; total time=   0.0s
# [CV] END max_depth=8, min_samples_leaf=8, min_samples_split=8; total time=   0.0s
# [CV] END max_depth=8, min_samples_leaf=8, min_samples_split=9; total time=   0.0s
# [CV] END max_depth=8, min_samples_leaf=8, min_samples_split=9; total time=   0.0s
# [CV] END max_depth=8, min_samples_leaf=8, min_samples_split=9; total time=   0.0s
# [CV] END max_depth=8, min_samples_leaf=8, min_samples_split=9; total time=   0.0s
# [CV] END max_depth=8, min_samples_leaf=8, min_samples_split=9; total time=   0.0s
# [CV] END max_depth=8, min_samples_leaf=8, min_samples_split=10; total time=   0.0s
# [CV] END max_depth=8, min_samples_leaf=8, min_samples_split=10; total time=   0.0s
# [CV] END max_depth=8, min_samples_leaf=8, min_samples_split=10; total time=   0.0s
# [CV] END max_depth=8, min_samples_leaf=8, min_samples_split=10; total time=   0.0s
# [CV] END max_depth=8, min_samples_leaf=8, min_samples_split=10; total time=   0.0s
# [CV] END max_depth=8, min_samples_leaf=9, min_samples_split=8; total time=   0.0s
# [CV] END max_depth=8, min_samples_leaf=9, min_samples_split=8; total time=   0.0s
# [CV] END max_depth=8, min_samples_leaf=9, min_samples_split=8; total time=   0.0s
# [CV] END max_depth=8, min_samples_leaf=9, min_samples_split=8; total time=   0.0s
# [CV] END max_depth=8, min_samples_leaf=9, min_samples_split=8; total time=   0.0s
# [CV] END max_depth=8, min_samples_leaf=9, min_samples_split=9; total time=   0.0s
# [CV] END max_depth=8, min_samples_leaf=9, min_samples_split=9; total time=   0.0s
# [CV] END max_depth=8, min_samples_leaf=9, min_samples_split=9; total time=   0.0s
# [CV] END max_depth=8, min_samples_leaf=9, min_samples_split=9; total time=   0.0s
# [CV] END max_depth=8, min_samples_leaf=9, min_samples_split=9; total time=   0.0s
# [CV] END max_depth=8, min_samples_leaf=9, min_samples_split=10; total time=   0.0s
# [CV] END max_depth=8, min_samples_leaf=9, min_samples_split=10; total time=   0.0s
# [CV] END max_depth=8, min_samples_leaf=9, min_samples_split=10; total time=   0.0s
# [CV] END max_depth=8, min_samples_leaf=9, min_samples_split=10; total time=   0.0s
# [CV] END max_depth=8, min_samples_leaf=9, min_samples_split=10; total time=   0.0s
# [CV] END max_depth=8, min_samples_leaf=10, min_samples_split=8; total time=   0.0s
# [CV] END max_depth=8, min_samples_leaf=10, min_samples_split=8; total time=   0.0s
# [CV] END max_depth=8, min_samples_leaf=10, min_samples_split=8; total time=   0.0s
# [CV] END max_depth=8, min_samples_leaf=10, min_samples_split=8; total time=   0.0s
# [CV] END max_depth=8, min_samples_leaf=10, min_samples_split=8; total time=   0.0s
# [CV] END max_depth=8, min_samples_leaf=10, min_samples_split=9; total time=   0.0s
# [CV] END max_depth=8, min_samples_leaf=10, min_samples_split=9; total time=   0.0s
# [CV] END max_depth=8, min_samples_leaf=10, min_samples_split=9; total time=   0.0s
# [CV] END max_depth=8, min_samples_leaf=10, min_samples_split=9; total time=   0.0s
# [CV] END max_depth=8, min_samples_leaf=10, min_samples_split=9; total time=   0.0s
# [CV] END max_depth=8, min_samples_leaf=10, min_samples_split=10; total time=   0.0s
# [CV] END max_depth=8, min_samples_leaf=10, min_samples_split=10; total time=   0.0s
# [CV] END max_depth=8, min_samples_leaf=10, min_samples_split=10; total time=   0.0s
# [CV] END max_depth=8, min_samples_leaf=10, min_samples_split=10; total time=   0.0s
# [CV] END max_depth=8, min_samples_leaf=10, min_samples_split=10; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=6, min_samples_split=8; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=6, min_samples_split=8; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=6, min_samples_split=8; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=6, min_samples_split=8; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=6, min_samples_split=8; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=6, min_samples_split=9; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=6, min_samples_split=9; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=6, min_samples_split=9; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=6, min_samples_split=9; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=6, min_samples_split=9; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=6, min_samples_split=10; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=6, min_samples_split=10; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=6, min_samples_split=10; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=6, min_samples_split=10; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=6, min_samples_split=10; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=7, min_samples_split=8; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=7, min_samples_split=8; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=7, min_samples_split=8; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=7, min_samples_split=8; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=7, min_samples_split=8; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=7, min_samples_split=9; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=7, min_samples_split=9; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=7, min_samples_split=9; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=7, min_samples_split=9; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=7, min_samples_split=9; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=7, min_samples_split=10; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=7, min_samples_split=10; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=7, min_samples_split=10; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=7, min_samples_split=10; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=7, min_samples_split=10; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=8, min_samples_split=8; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=8, min_samples_split=8; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=8, min_samples_split=8; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=8, min_samples_split=8; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=8, min_samples_split=8; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=8, min_samples_split=9; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=8, min_samples_split=9; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=8, min_samples_split=9; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=8, min_samples_split=9; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=8, min_samples_split=9; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=8, min_samples_split=10; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=8, min_samples_split=10; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=8, min_samples_split=10; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=8, min_samples_split=10; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=8, min_samples_split=10; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=9, min_samples_split=8; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=9, min_samples_split=8; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=9, min_samples_split=8; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=9, min_samples_split=8; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=9, min_samples_split=8; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=9, min_samples_split=9; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=9, min_samples_split=9; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=9, min_samples_split=9; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=9, min_samples_split=9; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=9, min_samples_split=9; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=9, min_samples_split=10; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=9, min_samples_split=10; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=9, min_samples_split=10; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=9, min_samples_split=10; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=9, min_samples_split=10; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=10, min_samples_split=8; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=10, min_samples_split=8; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=10, min_samples_split=8; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=10, min_samples_split=8; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=10, min_samples_split=8; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=10, min_samples_split=9; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=10, min_samples_split=9; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=10, min_samples_split=9; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=10, min_samples_split=9; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=10, min_samples_split=9; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=10, min_samples_split=10; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=10, min_samples_split=10; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=10, min_samples_split=10; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=10, min_samples_split=10; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=10, min_samples_split=10; total time=   0.0s
# [CV] END max_depth=10, min_samples_leaf=6, min_samples_split=8; total time=   0.0s
# [CV] END max_depth=10, min_samples_leaf=6, min_samples_split=8; total time=   0.0s
# [CV] END max_depth=10, min_samples_leaf=6, min_samples_split=8; total time=   0.0s
# [CV] END max_depth=10, min_samples_leaf=6, min_samples_split=8; total time=   0.0s
# [CV] END max_depth=10, min_samples_leaf=6, min_samples_split=8; total time=   0.0s
# [CV] END max_depth=10, min_samples_leaf=6, min_samples_split=9; total time=   0.0s
# [CV] END max_depth=10, min_samples_leaf=6, min_samples_split=9; total time=   0.0s
# [CV] END max_depth=10, min_samples_leaf=6, min_samples_split=9; total time=   0.0s
# [CV] END max_depth=10, min_samples_leaf=6, min_samples_split=9; total time=   0.0s
# [CV] END max_depth=10, min_samples_leaf=6, min_samples_split=9; total time=   0.0s
# [CV] END max_depth=10, min_samples_leaf=6, min_samples_split=10; total time=   0.0s
# [CV] END max_depth=10, min_samples_leaf=6, min_samples_split=10; total time=   0.0s
# [CV] END max_depth=10, min_samples_leaf=6, min_samples_split=10; total time=   0.0s
# [CV] END max_depth=10, min_samples_leaf=6, min_samples_split=10; total time=   0.0s
# [CV] END max_depth=10, min_samples_leaf=6, min_samples_split=10; total time=   0.0s
# [CV] END max_depth=10, min_samples_leaf=7, min_samples_split=8; total time=   0.0s
# [CV] END max_depth=10, min_samples_leaf=7, min_samples_split=8; total time=   0.0s
# [CV] END max_depth=10, min_samples_leaf=7, min_samples_split=8; total time=   0.0s
# [CV] END max_depth=10, min_samples_leaf=7, min_samples_split=8; total time=   0.0s
# [CV] END max_depth=10, min_samples_leaf=7, min_samples_split=8; total time=   0.0s
# [CV] END max_depth=10, min_samples_leaf=7, min_samples_split=9; total time=   0.0s
# [CV] END max_depth=10, min_samples_leaf=7, min_samples_split=9; total time=   0.0s
# [CV] END max_depth=10, min_samples_leaf=7, min_samples_split=9; total time=   0.0s
# [CV] END max_depth=10, min_samples_leaf=7, min_samples_split=9; total time=   0.0s
# [CV] END max_depth=10, min_samples_leaf=7, min_samples_split=9; total time=   0.0s
# [CV] END max_depth=10, min_samples_leaf=7, min_samples_split=10; total time=   0.0s
# [CV] END max_depth=10, min_samples_leaf=7, min_samples_split=10; total time=   0.0s
# [CV] END max_depth=10, min_samples_leaf=7, min_samples_split=10; total time=   0.0s
# [CV] END max_depth=10, min_samples_leaf=7, min_samples_split=10; total time=   0.0s
# [CV] END max_depth=10, min_samples_leaf=7, min_samples_split=10; total time=   0.0s
# [CV] END max_depth=10, min_samples_leaf=8, min_samples_split=8; total time=   0.0s
# [CV] END max_depth=10, min_samples_leaf=8, min_samples_split=8; total time=   0.0s
# [CV] END max_depth=10, min_samples_leaf=8, min_samples_split=8; total time=   0.0s
# [CV] END max_depth=10, min_samples_leaf=8, min_samples_split=8; total time=   0.0s
# [CV] END max_depth=10, min_samples_leaf=8, min_samples_split=8; total time=   0.0s
# [CV] END max_depth=10, min_samples_leaf=8, min_samples_split=9; total time=   0.0s
# [CV] END max_depth=10, min_samples_leaf=8, min_samples_split=9; total time=   0.0s
# [CV] END max_depth=10, min_samples_leaf=8, min_samples_split=9; total time=   0.0s
# [CV] END max_depth=10, min_samples_leaf=8, min_samples_split=9; total time=   0.0s
# [CV] END max_depth=10, min_samples_leaf=8, min_samples_split=9; total time=   0.0s
# [CV] END max_depth=10, min_samples_leaf=8, min_samples_split=10; total time=   0.0s
# [CV] END max_depth=10, min_samples_leaf=8, min_samples_split=10; total time=   0.0s
# [CV] END max_depth=10, min_samples_leaf=8, min_samples_split=10; total time=   0.0s
# [CV] END max_depth=10, min_samples_leaf=8, min_samples_split=10; total time=   0.0s
# [CV] END max_depth=10, min_samples_leaf=8, min_samples_split=10; total time=   0.0s
# [CV] END max_depth=10, min_samples_leaf=9, min_samples_split=8; total time=   0.0s
# [CV] END max_depth=10, min_samples_leaf=9, min_samples_split=8; total time=   0.0s
# [CV] END max_depth=10, min_samples_leaf=9, min_samples_split=8; total time=   0.0s
# [CV] END max_depth=10, min_samples_leaf=9, min_samples_split=8; total time=   0.0s
# [CV] END max_depth=10, min_samples_leaf=9, min_samples_split=8; total time=   0.0s
# [CV] END max_depth=10, min_samples_leaf=9, min_samples_split=9; total time=   0.0s
# [CV] END max_depth=10, min_samples_leaf=9, min_samples_split=9; total time=   0.0s
# [CV] END max_depth=10, min_samples_leaf=9, min_samples_split=9; total time=   0.0s
# [CV] END max_depth=10, min_samples_leaf=9, min_samples_split=9; total time=   0.0s
# [CV] END max_depth=10, min_samples_leaf=9, min_samples_split=9; total time=   0.0s
# [CV] END max_depth=10, min_samples_leaf=9, min_samples_split=10; total time=   0.0s
# [CV] END max_depth=10, min_samples_leaf=9, min_samples_split=10; total time=   0.0s
# [CV] END max_depth=10, min_samples_leaf=9, min_samples_split=10; total time=   0.0s
# [CV] END max_depth=10, min_samples_leaf=9, min_samples_split=10; total time=   0.0s
# [CV] END max_depth=10, min_samples_leaf=9, min_samples_split=10; total time=   0.0s
# [CV] END max_depth=10, min_samples_leaf=10, min_samples_split=8; total time=   0.0s
# [CV] END max_depth=10, min_samples_leaf=10, min_samples_split=8; total time=   0.0s
# [CV] END max_depth=10, min_samples_leaf=10, min_samples_split=8; total time=   0.0s
# [CV] END max_depth=10, min_samples_leaf=10, min_samples_split=8; total time=   0.0s
# [CV] END max_depth=10, min_samples_leaf=10, min_samples_split=8; total time=   0.0s
# [CV] END max_depth=10, min_samples_leaf=10, min_samples_split=9; total time=   0.0s
# [CV] END max_depth=10, min_samples_leaf=10, min_samples_split=9; total time=   0.0s
# [CV] END max_depth=10, min_samples_leaf=10, min_samples_split=9; total time=   0.0s
# [CV] END max_depth=10, min_samples_leaf=10, min_samples_split=9; total time=   0.0s
# [CV] END max_depth=10, min_samples_leaf=10, min_samples_split=9; total time=   0.0s
# [CV] END max_depth=10, min_samples_leaf=10, min_samples_split=10; total time=   0.0s
# [CV] END max_depth=10, min_samples_leaf=10, min_samples_split=10; total time=   0.0s
# [CV] END max_depth=10, min_samples_leaf=10, min_samples_split=10; total time=   0.0s
# [CV] END max_depth=10, min_samples_leaf=10, min_samples_split=10; total time=   0.0s
# [CV] END max_depth=10, min_samples_leaf=10, min_samples_split=10; total time=   0.0s
# GridSearchCV(cv=5, estimator=DecisionTreeRegressor(),
#              param_grid={'max_depth': [8, 9, 10],
#                          'min_samples_leaf': [6, 7, 8, 9, 10],
#                          'min_samples_split': [8, 9, 10]},
#              scoring='roc_auc', verbose=2)

# %%
# BEST HYPER PARAMETER
rf_grid.best_params_
# Out:
# {'max_depth': 8, 'min_samples_leaf': 6, 'min_samples_split': 8}

# %%
# USING BEST HYPER PARAMENTER OM THE MODEL
t = DecisionTreeRegressor(max_depth = 8, min_samples_split = 8, min_samples_leaf = 6)

# %%
#  MODEL FITIING ON TRAIN DATASET
t.fit(X_train, Y_train)
# Out:
# DecisionTreeRegressor(max_depth=8, min_samples_leaf=6, min_samples_split=8)

# %%
# PREDICTING X_TEST
y_pred = t.predict(X_test)

# %%
# R_SQUARED
r2_score(Y_test, y_pred)
# Out:
# 0.802234540384112

# %%
#  MODEL FITIING ON TEST DATASET
t.score(X_test, Y_test)
# Out:
# 0.802234540384112

# %%
#  MODEL FITIING ON TRAIN DATASET
t.score(X_train, Y_train)
# Out:
# 0.8300829783880412

# %%
# ADJUSTED R-SQURED , MEAN SQUARED ERROR, ROOT MEAN SQUARED ERROR
print("Adjusted R2 : ",1-(1-r2_score((Y_test), (y_pred)))*((X_test.shape[0]-1)/(X_test.shape[0]-X_test.shape[1]-1)))
MSE  = mean_squared_error(Y_test, y_pred)
print("MSE :" , MSE)
RMSE = np.sqrt(MSE)
print("RMSE :" ,RMSE)
# Out:
# Adjusted R2 :  0.8007783750118828
# MSE : 80924.41687789347
# RMSE : 284.47217241391724

# %%
# PLOTTING FIRST 50 Y_TEST AND Y_PRED
plt.figure(figsize=(15,10))
plt.plot(np.array(Y_test[:50]), color = "orange")
plt.plot(y_pred[:50], color = "red")
plt.title("DecisionTreeRegressor")
plt.legend(["Predicted","Actual"])
plt.show()

# %% [markdown]
# RandomForest

# %%
# IMPORTING RandomForestRegressor
from sklearn.ensemble import RandomForestRegressor

# %%
# PERFORMING HYPERPARAMETER TUNNING AND FITTING THE TRAIN DATASET 
rf_grid = GridSearchCV( RandomForestRegressor(),
                       param_grid = {'max_depth' : [18,19,20], 'min_samples_split' : [7,8,9], 'min_samples_leaf' : [7,6,8]},
                       cv = 5, verbose=2, scoring='roc_auc')

rf_grid.fit(X_train,Y_train)
# Out:
# Fitting 5 folds for each of 27 candidates, totalling 135 fits
# [CV] END max_depth=18, min_samples_leaf=7, min_samples_split=7; total time=   1.7s
# [CV] END max_depth=18, min_samples_leaf=7, min_samples_split=7; total time=   1.7s
# [CV] END max_depth=18, min_samples_leaf=7, min_samples_split=7; total time=   1.7s
# [CV] END max_depth=18, min_samples_leaf=7, min_samples_split=7; total time=   1.7s
# [CV] END max_depth=18, min_samples_leaf=7, min_samples_split=7; total time=   1.7s
# [CV] END max_depth=18, min_samples_leaf=7, min_samples_split=8; total time=   1.7s
# [CV] END max_depth=18, min_samples_leaf=7, min_samples_split=8; total time=   1.7s
# [CV] END max_depth=18, min_samples_leaf=7, min_samples_split=8; total time=   1.7s
# [CV] END max_depth=18, min_samples_leaf=7, min_samples_split=8; total time=   1.7s
# [CV] END max_depth=18, min_samples_leaf=7, min_samples_split=8; total time=   2.4s
# [CV] END max_depth=18, min_samples_leaf=7, min_samples_split=9; total time=   1.6s
# [CV] END max_depth=18, min_samples_leaf=7, min_samples_split=9; total time=   1.7s
# [CV] END max_depth=18, min_samples_leaf=7, min_samples_split=9; total time=   1.7s
# [CV] END max_depth=18, min_samples_leaf=7, min_samples_split=9; total time=   1.7s
# [CV] END max_depth=18, min_samples_leaf=7, min_samples_split=9; total time=   1.7s
# [CV] END max_depth=18, min_samples_leaf=6, min_samples_split=7; total time=   1.7s
# [CV] END max_depth=18, min_samples_leaf=6, min_samples_split=7; total time=   1.7s
# [CV] END max_depth=18, min_samples_leaf=6, min_samples_split=7; total time=   1.7s
# [CV] END max_depth=18, min_samples_leaf=6, min_samples_split=7; total time=   1.7s
# [CV] END max_depth=18, min_samples_leaf=6, min_samples_split=7; total time=   1.7s
# [CV] END max_depth=18, min_samples_leaf=6, min_samples_split=8; total time=   1.7s
# [CV] END max_depth=18, min_samples_leaf=6, min_samples_split=8; total time=   1.7s
# [CV] END max_depth=18, min_samples_leaf=6, min_samples_split=8; total time=   1.7s
# [CV] END max_depth=18, min_samples_leaf=6, min_samples_split=8; total time=   1.7s
# [CV] END max_depth=18, min_samples_leaf=6, min_samples_split=8; total time=   1.7s
# [CV] END max_depth=18, min_samples_leaf=6, min_samples_split=9; total time=   1.7s
# [CV] END max_depth=18, min_samples_leaf=6, min_samples_split=9; total time=   1.7s
# [CV] END max_depth=18, min_samples_leaf=6, min_samples_split=9; total time=   1.7s
# [CV] END max_depth=18, min_samples_leaf=6, min_samples_split=9; total time=   1.7s
# [CV] END max_depth=18, min_samples_leaf=6, min_samples_split=9; total time=   1.7s
# [CV] END max_depth=18, min_samples_leaf=8, min_samples_split=7; total time=   1.6s
# [CV] END max_depth=18, min_samples_leaf=8, min_samples_split=7; total time=   1.6s
# [CV] END max_depth=18, min_samples_leaf=8, min_samples_split=7; total time=   1.6s
# [CV] END max_depth=18, min_samples_leaf=8, min_samples_split=7; total time=   1.6s
# [CV] END max_depth=18, min_samples_leaf=8, min_samples_split=7; total time=   1.6s
# [CV] END max_depth=18, min_samples_leaf=8, min_samples_split=8; total time=   1.6s
# [CV] END max_depth=18, min_samples_leaf=8, min_samples_split=8; total time=   1.6s
# [CV] END max_depth=18, min_samples_leaf=8, min_samples_split=8; total time=   1.6s
# [CV] END max_depth=18, min_samples_leaf=8, min_samples_split=8; total time=   1.6s
# [CV] END max_depth=18, min_samples_leaf=8, min_samples_split=8; total time=   1.6s
# [CV] END max_depth=18, min_samples_leaf=8, min_samples_split=9; total time=   1.6s
# [CV] END max_depth=18, min_samples_leaf=8, min_samples_split=9; total time=   1.6s
# [CV] END max_depth=18, min_samples_leaf=8, min_samples_split=9; total time=   1.6s
# [CV] END max_depth=18, min_samples_leaf=8, min_samples_split=9; total time=   1.7s
# [CV] END max_depth=18, min_samples_leaf=8, min_samples_split=9; total time=   1.6s
# [CV] END max_depth=19, min_samples_leaf=7, min_samples_split=7; total time=   1.7s
# [CV] END max_depth=19, min_samples_leaf=7, min_samples_split=7; total time=   1.7s
# [CV] END max_depth=19, min_samples_leaf=7, min_samples_split=7; total time=   1.7s
# [CV] END max_depth=19, min_samples_leaf=7, min_samples_split=7; total time=   1.7s
# [CV] END max_depth=19, min_samples_leaf=7, min_samples_split=7; total time=   1.7s
# [CV] END max_depth=19, min_samples_leaf=7, min_samples_split=8; total time=   1.7s
# [CV] END max_depth=19, min_samples_leaf=7, min_samples_split=8; total time=   1.7s
# [CV] END max_depth=19, min_samples_leaf=7, min_samples_split=8; total time=   1.7s
# [CV] END max_depth=19, min_samples_leaf=7, min_samples_split=8; total time=   1.7s
# [CV] END max_depth=19, min_samples_leaf=7, min_samples_split=8; total time=   1.7s
# [CV] END max_depth=19, min_samples_leaf=7, min_samples_split=9; total time=   1.7s
# [CV] END max_depth=19, min_samples_leaf=7, min_samples_split=9; total time=   1.7s
# [CV] END max_depth=19, min_samples_leaf=7, min_samples_split=9; total time=   1.7s
# [CV] END max_depth=19, min_samples_leaf=7, min_samples_split=9; total time=   1.7s
# [CV] END max_depth=19, min_samples_leaf=7, min_samples_split=9; total time=   1.7s
# [CV] END max_depth=19, min_samples_leaf=6, min_samples_split=7; total time=   1.7s
# [CV] END max_depth=19, min_samples_leaf=6, min_samples_split=7; total time=   1.7s
# [CV] END max_depth=19, min_samples_leaf=6, min_samples_split=7; total time=   1.7s
# [CV] END max_depth=19, min_samples_leaf=6, min_samples_split=7; total time=   1.7s
# [CV] END max_depth=19, min_samples_leaf=6, min_samples_split=7; total time=   1.7s
# [CV] END max_depth=19, min_samples_leaf=6, min_samples_split=8; total time=   1.7s
# [CV] END max_depth=19, min_samples_leaf=6, min_samples_split=8; total time=   1.7s
# [CV] END max_depth=19, min_samples_leaf=6, min_samples_split=8; total time=   1.7s
# [CV] END max_depth=19, min_samples_leaf=6, min_samples_split=8; total time=   1.7s
# [CV] END max_depth=19, min_samples_leaf=6, min_samples_split=8; total time=   1.7s
# [CV] END max_depth=19, min_samples_leaf=6, min_samples_split=9; total time=   1.7s
# [CV] END max_depth=19, min_samples_leaf=6, min_samples_split=9; total time=   1.7s
# [CV] END max_depth=19, min_samples_leaf=6, min_samples_split=9; total time=   1.7s
# [CV] END max_depth=19, min_samples_leaf=6, min_samples_split=9; total time=   1.7s
# [CV] END max_depth=19, min_samples_leaf=6, min_samples_split=9; total time=   1.7s
# [CV] END max_depth=19, min_samples_leaf=8, min_samples_split=7; total time=   1.6s
# [CV] END max_depth=19, min_samples_leaf=8, min_samples_split=7; total time=   1.6s
# [CV] END max_depth=19, min_samples_leaf=8, min_samples_split=7; total time=   1.6s
# [CV] END max_depth=19, min_samples_leaf=8, min_samples_split=7; total time=   1.6s
# [CV] END max_depth=19, min_samples_leaf=8, min_samples_split=7; total time=   1.6s
# [CV] END max_depth=19, min_samples_leaf=8, min_samples_split=8; total time=   1.6s
# [CV] END max_depth=19, min_samples_leaf=8, min_samples_split=8; total time=   1.6s
# [CV] END max_depth=19, min_samples_leaf=8, min_samples_split=8; total time=   1.6s
# [CV] END max_depth=19, min_samples_leaf=8, min_samples_split=8; total time=   1.6s
# [CV] END max_depth=19, min_samples_leaf=8, min_samples_split=8; total time=   1.6s
# [CV] END max_depth=19, min_samples_leaf=8, min_samples_split=9; total time=   1.6s
# [CV] END max_depth=19, min_samples_leaf=8, min_samples_split=9; total time=   1.6s
# [CV] END max_depth=19, min_samples_leaf=8, min_samples_split=9; total time=   1.6s
# [CV] END max_depth=19, min_samples_leaf=8, min_samples_split=9; total time=   1.6s
# [CV] END max_depth=19, min_samples_leaf=8, min_samples_split=9; total time=   1.6s
# [CV] END max_depth=20, min_samples_leaf=7, min_samples_split=7; total time=   1.7s
# [CV] END max_depth=20, min_samples_leaf=7, min_samples_split=7; total time=   1.7s
# [CV] END max_depth=20, min_samples_leaf=7, min_samples_split=7; total time=   1.7s
# [CV] END max_depth=20, min_samples_leaf=7, min_samples_split=7; total time=   1.7s
# [CV] END max_depth=20, min_samples_leaf=7, min_samples_split=7; total time=   1.7s
# [CV] END max_depth=20, min_samples_leaf=7, min_samples_split=8; total time=   1.7s
# [CV] END max_depth=20, min_samples_leaf=7, min_samples_split=8; total time=   1.7s
# [CV] END max_depth=20, min_samples_leaf=7, min_samples_split=8; total time=   1.7s
# [CV] END max_depth=20, min_samples_leaf=7, min_samples_split=8; total time=   1.7s
# [CV] END max_depth=20, min_samples_leaf=7, min_samples_split=8; total time=   1.7s
# [CV] END max_depth=20, min_samples_leaf=7, min_samples_split=9; total time=   1.7s
# [CV] END max_depth=20, min_samples_leaf=7, min_samples_split=9; total time=   1.7s
# [CV] END max_depth=20, min_samples_leaf=7, min_samples_split=9; total time=   1.7s
# [CV] END max_depth=20, min_samples_leaf=7, min_samples_split=9; total time=   1.7s
# [CV] END max_depth=20, min_samples_leaf=7, min_samples_split=9; total time=   1.7s
# [CV] END max_depth=20, min_samples_leaf=6, min_samples_split=7; total time=   1.7s
# [CV] END max_depth=20, min_samples_leaf=6, min_samples_split=7; total time=   1.7s
# [CV] END max_depth=20, min_samples_leaf=6, min_samples_split=7; total time=   1.7s
# [CV] END max_depth=20, min_samples_leaf=6, min_samples_split=7; total time=   1.7s
# [CV] END max_depth=20, min_samples_leaf=6, min_samples_split=7; total time=   1.7s
# [CV] END max_depth=20, min_samples_leaf=6, min_samples_split=8; total time=   1.7s
# [CV] END max_depth=20, min_samples_leaf=6, min_samples_split=8; total time=   1.7s
# [CV] END max_depth=20, min_samples_leaf=6, min_samples_split=8; total time=   1.7s
# [CV] END max_depth=20, min_samples_leaf=6, min_samples_split=8; total time=   1.7s
# [CV] END max_depth=20, min_samples_leaf=6, min_samples_split=8; total time=   1.7s
# [CV] END max_depth=20, min_samples_leaf=6, min_samples_split=9; total time=   1.7s
# [CV] END max_depth=20, min_samples_leaf=6, min_samples_split=9; total time=   1.7s
# [CV] END max_depth=20, min_samples_leaf=6, min_samples_split=9; total time=   1.7s
# [CV] END max_depth=20, min_samples_leaf=6, min_samples_split=9; total time=   1.7s
# [CV] END max_depth=20, min_samples_leaf=6, min_samples_split=9; total time=   1.7s
# [CV] END max_depth=20, min_samples_leaf=8, min_samples_split=7; total time=   1.6s
# [CV] END max_depth=20, min_samples_leaf=8, min_samples_split=7; total time=   1.6s
# [CV] END max_depth=20, min_samples_leaf=8, min_samples_split=7; total time=   1.6s
# [CV] END max_depth=20, min_samples_leaf=8, min_samples_split=7; total time=   1.6s
# [CV] END max_depth=20, min_samples_leaf=8, min_samples_split=7; total time=   1.6s
# [CV] END max_depth=20, min_samples_leaf=8, min_samples_split=8; total time=   1.6s
# [CV] END max_depth=20, min_samples_leaf=8, min_samples_split=8; total time=   1.6s
# [CV] END max_depth=20, min_samples_leaf=8, min_samples_split=8; total time=   1.6s
# [CV] END max_depth=20, min_samples_leaf=8, min_samples_split=8; total time=   1.6s
# [CV] END max_depth=20, min_samples_leaf=8, min_samples_split=8; total time=   1.6s
# [CV] END max_depth=20, min_samples_leaf=8, min_samples_split=9; total time=   1.6s
# [CV] END max_depth=20, min_samples_leaf=8, min_samples_split=9; total time=   1.6s
# [CV] END max_depth=20, min_samples_leaf=8, min_samples_split=9; total time=   1.6s
# [CV] END max_depth=20, min_samples_leaf=8, min_samples_split=9; total time=   1.6s
# [CV] END max_depth=20, min_samples_leaf=8, min_samples_split=9; total time=   1.6s
# GridSearchCV(cv=5, estimator=RandomForestRegressor(),
#              param_grid={'max_depth': [18, 19, 20],
#                          'min_samples_leaf': [7, 6, 8],
#                          'min_samples_split': [7, 8, 9]},
#              scoring='roc_auc', verbose=2)

# %%
# BEST HYPER PARAMETER
rf_grid.best_params_
# Out:
# {'max_depth': 18, 'min_samples_leaf': 7, 'min_samples_split': 7}

# %%
# USING BEST HYPER PARAMENTER OM THE MODEL
rfr = RandomForestRegressor(max_depth = 18, min_samples_split = 7, min_samples_leaf = 7)

# %%
#  MODEL FITIING ON TRAIN DATASET
rfr.fit(X_train, Y_train)
# Out:
# RandomForestRegressor(max_depth=18, min_samples_leaf=7, min_samples_split=7)

# %%
# PREDICTING X_TEST
y_pred = rfr.predict(X_test)

# %%
#  MODEL FITIING ON TRAIN DATASET
rfr.score(X_train, Y_train)
# Out:
# 0.9267497903592081

# %%
# #  MODEL FITIING ON TEST DATASET
rfr.score(X_test, Y_test)
# Out:
# 0.8730178795569363

# %%
# R_SQUARED
r2_score(Y_test , y_pred)
# Out:
# 0.8730178795569363

# %%
# ADJUSTED R-SQURED , MEAN SQUARED ERROR, ROOT MEAN SQUARED ERROR
print("Adjusted R2 : ",1-(1-r2_score((Y_test), (y_pred)))*((X_test.shape[0]-1)/(X_test.shape[0]-X_test.shape[1]-1)))
MSE  = mean_squared_error(Y_test, y_pred)
print("MSE :" , MSE)
RMSE = np.sqrt(MSE)
print("RMSE :" ,RMSE)
# Out:
# Adjusted R2 :  0.872082898458414
# MSE : 51960.307278793494
# RMSE : 227.94803635652028

# %%
# PLOTTING FIRST 50 Y_TEST AND Y_PRED
plt.figure(figsize=(15,10))
plt.plot(np.array(Y_test[:50]), color = "orange")
plt.plot(y_pred[:50], color = "red")
plt.title("RandomForestRegressor")
plt.legend(["Predicted","Actual"])
plt.show()

# %% [markdown]
# ADA BOOSTIKNG

# %%
# IMPORTING AdaBoostRegressor
from sklearn.ensemble import AdaBoostRegressor

# %%
# PERFORMING HYPERPARAMETER TUNNING
rf_grid = GridSearchCV( AdaBoostRegressor(),
                       param_grid = { 'n_estimators' :[50, 60], 'learning_rate' : [1.0,0.75], 'loss' :['linear', 'square' , 'exponential'], "random_state" : [0,1,2]}, cv=3
                       , verbose=2, scoring='roc_auc')

# %%
# FITTING THE TRAIN DATASET 
rf_grid.fit(X_train,Y_train)
# Out:
# Fitting 3 folds for each of 36 candidates, totalling 108 fits
# [CV] END learning_rate=1.0, loss=linear, n_estimators=50, random_state=0; total time=   0.4s
# [CV] END learning_rate=1.0, loss=linear, n_estimators=50, random_state=0; total time=   0.4s
# [CV] END learning_rate=1.0, loss=linear, n_estimators=50, random_state=0; total time=   0.4s
# [CV] END learning_rate=1.0, loss=linear, n_estimators=50, random_state=1; total time=   0.4s
# [CV] END learning_rate=1.0, loss=linear, n_estimators=50, random_state=1; total time=   0.4s
# [CV] END learning_rate=1.0, loss=linear, n_estimators=50, random_state=1; total time=   0.4s
# [CV] END learning_rate=1.0, loss=linear, n_estimators=50, random_state=2; total time=   0.4s
# [CV] END learning_rate=1.0, loss=linear, n_estimators=50, random_state=2; total time=   0.4s
# [CV] END learning_rate=1.0, loss=linear, n_estimators=50, random_state=2; total time=   0.4s
# [CV] END learning_rate=1.0, loss=linear, n_estimators=60, random_state=0; total time=   0.4s
# [CV] END learning_rate=1.0, loss=linear, n_estimators=60, random_state=0; total time=   0.4s
# [CV] END learning_rate=1.0, loss=linear, n_estimators=60, random_state=0; total time=   0.4s
# [CV] END learning_rate=1.0, loss=linear, n_estimators=60, random_state=1; total time=   0.4s
# [CV] END learning_rate=1.0, loss=linear, n_estimators=60, random_state=1; total time=   0.4s
# [CV] END learning_rate=1.0, loss=linear, n_estimators=60, random_state=1; total time=   0.4s
# [CV] END learning_rate=1.0, loss=linear, n_estimators=60, random_state=2; total time=   0.4s
# [CV] END learning_rate=1.0, loss=linear, n_estimators=60, random_state=2; total time=   0.4s
# [CV] END learning_rate=1.0, loss=linear, n_estimators=60, random_state=2; total time=   0.4s
# [CV] END learning_rate=1.0, loss=square, n_estimators=50, random_state=0; total time=   0.3s
# [CV] END learning_rate=1.0, loss=square, n_estimators=50, random_state=0; total time=   0.3s
# [CV] END learning_rate=1.0, loss=square, n_estimators=50, random_state=0; total time=   0.3s
# [CV] END learning_rate=1.0, loss=square, n_estimators=50, random_state=1; total time=   0.3s
# [CV] END learning_rate=1.0, loss=square, n_estimators=50, random_state=1; total time=   0.3s
# [CV] END learning_rate=1.0, loss=square, n_estimators=50, random_state=1; total time=   0.3s
# [CV] END learning_rate=1.0, loss=square, n_estimators=50, random_state=2; total time=   0.3s
# [CV] END learning_rate=1.0, loss=square, n_estimators=50, random_state=2; total time=   0.3s
# [CV] END learning_rate=1.0, loss=square, n_estimators=50, random_state=2; total time=   0.3s
# [CV] END learning_rate=1.0, loss=square, n_estimators=60, random_state=0; total time=   0.4s
# [CV] END learning_rate=1.0, loss=square, n_estimators=60, random_state=0; total time=   0.4s
# [CV] END learning_rate=1.0, loss=square, n_estimators=60, random_state=0; total time=   0.4s
# [CV] END learning_rate=1.0, loss=square, n_estimators=60, random_state=1; total time=   0.4s
# [CV] END learning_rate=1.0, loss=square, n_estimators=60, random_state=1; total time=   0.4s
# [CV] END learning_rate=1.0, loss=square, n_estimators=60, random_state=1; total time=   0.4s
# [CV] END learning_rate=1.0, loss=square, n_estimators=60, random_state=2; total time=   0.4s
# [CV] END learning_rate=1.0, loss=square, n_estimators=60, random_state=2; total time=   0.4s
# [CV] END learning_rate=1.0, loss=square, n_estimators=60, random_state=2; total time=   0.4s
# [CV] END learning_rate=1.0, loss=exponential, n_estimators=50, random_state=0; total time=   0.4s
# [CV] END learning_rate=1.0, loss=exponential, n_estimators=50, random_state=0; total time=   0.4s
# [CV] END learning_rate=1.0, loss=exponential, n_estimators=50, random_state=0; total time=   0.4s
# [CV] END learning_rate=1.0, loss=exponential, n_estimators=50, random_state=1; total time=   0.4s
# [CV] END learning_rate=1.0, loss=exponential, n_estimators=50, random_state=1; total time=   0.4s
# [CV] END learning_rate=1.0, loss=exponential, n_estimators=50, random_state=1; total time=   0.4s
# [CV] END learning_rate=1.0, loss=exponential, n_estimators=50, random_state=2; total time=   0.4s
# [CV] END learning_rate=1.0, loss=exponential, n_estimators=50, random_state=2; total time=   0.4s
# [CV] END learning_rate=1.0, loss=exponential, n_estimators=50, random_state=2; total time=   0.4s
# [CV] END learning_rate=1.0, loss=exponential, n_estimators=60, random_state=0; total time=   0.4s
# [CV] END learning_rate=1.0, loss=exponential, n_estimators=60, random_state=0; total time=   0.4s
# [CV] END learning_rate=1.0, loss=exponential, n_estimators=60, random_state=0; total time=   0.4s
# [CV] END learning_rate=1.0, loss=exponential, n_estimators=60, random_state=1; total time=   0.4s
# [CV] END learning_rate=1.0, loss=exponential, n_estimators=60, random_state=1; total time=   0.4s
# [CV] END learning_rate=1.0, loss=exponential, n_estimators=60, random_state=1; total time=   0.4s
# [CV] END learning_rate=1.0, loss=exponential, n_estimators=60, random_state=2; total time=   0.4s
# [CV] END learning_rate=1.0, loss=exponential, n_estimators=60, random_state=2; total time=   0.4s
# [CV] END learning_rate=1.0, loss=exponential, n_estimators=60, random_state=2; total time=   0.4s
# [CV] END learning_rate=0.75, loss=linear, n_estimators=50, random_state=0; total time=   0.4s
# [CV] END learning_rate=0.75, loss=linear, n_estimators=50, random_state=0; total time=   0.4s
# [CV] END learning_rate=0.75, loss=linear, n_estimators=50, random_state=0; total time=   0.4s
# [CV] END learning_rate=0.75, loss=linear, n_estimators=50, random_state=1; total time=   0.4s
# [CV] END learning_rate=0.75, loss=linear, n_estimators=50, random_state=1; total time=   0.4s
# [CV] END learning_rate=0.75, loss=linear, n_estimators=50, random_state=1; total time=   0.4s
# [CV] END learning_rate=0.75, loss=linear, n_estimators=50, random_state=2; total time=   0.4s
# [CV] END learning_rate=0.75, loss=linear, n_estimators=50, random_state=2; total time=   0.4s
# [CV] END learning_rate=0.75, loss=linear, n_estimators=50, random_state=2; total time=   0.4s
# [CV] END learning_rate=0.75, loss=linear, n_estimators=60, random_state=0; total time=   0.4s
# [CV] END learning_rate=0.75, loss=linear, n_estimators=60, random_state=0; total time=   0.4s
# [CV] END learning_rate=0.75, loss=linear, n_estimators=60, random_state=0; total time=   0.4s
# [CV] END learning_rate=0.75, loss=linear, n_estimators=60, random_state=1; total time=   0.4s
# [CV] END learning_rate=0.75, loss=linear, n_estimators=60, random_state=1; total time=   0.4s
# [CV] END learning_rate=0.75, loss=linear, n_estimators=60, random_state=1; total time=   0.4s
# [CV] END learning_rate=0.75, loss=linear, n_estimators=60, random_state=2; total time=   0.4s
# [CV] END learning_rate=0.75, loss=linear, n_estimators=60, random_state=2; total time=   0.4s
# [CV] END learning_rate=0.75, loss=linear, n_estimators=60, random_state=2; total time=   0.4s
# [CV] END learning_rate=0.75, loss=square, n_estimators=50, random_state=0; total time=   0.3s
# [CV] END learning_rate=0.75, loss=square, n_estimators=50, random_state=0; total time=   0.3s
# [CV] END learning_rate=0.75, loss=square, n_estimators=50, random_state=0; total time=   0.3s
# [CV] END learning_rate=0.75, loss=square, n_estimators=50, random_state=1; total time=   0.3s
# [CV] END learning_rate=0.75, loss=square, n_estimators=50, random_state=1; total time=   0.3s
# [CV] END learning_rate=0.75, loss=square, n_estimators=50, random_state=1; total time=   0.3s
# [CV] END learning_rate=0.75, loss=square, n_estimators=50, random_state=2; total time=   0.3s
# [CV] END learning_rate=0.75, loss=square, n_estimators=50, random_state=2; total time=   0.3s
# [CV] END learning_rate=0.75, loss=square, n_estimators=50, random_state=2; total time=   0.4s
# [CV] END learning_rate=0.75, loss=square, n_estimators=60, random_state=0; total time=   0.4s
# [CV] END learning_rate=0.75, loss=square, n_estimators=60, random_state=0; total time=   0.4s
# [CV] END learning_rate=0.75, loss=square, n_estimators=60, random_state=0; total time=   0.4s
# [CV] END learning_rate=0.75, loss=square, n_estimators=60, random_state=1; total time=   0.4s
# [CV] END learning_rate=0.75, loss=square, n_estimators=60, random_state=1; total time=   0.4s
# [CV] END learning_rate=0.75, loss=square, n_estimators=60, random_state=1; total time=   0.4s
# [CV] END learning_rate=0.75, loss=square, n_estimators=60, random_state=2; total time=   0.4s
# [CV] END learning_rate=0.75, loss=square, n_estimators=60, random_state=2; total time=   0.4s
# [CV] END learning_rate=0.75, loss=square, n_estimators=60, random_state=2; total time=   0.4s
# [CV] END learning_rate=0.75, loss=exponential, n_estimators=50, random_state=0; total time=   0.4s
# [CV] END learning_rate=0.75, loss=exponential, n_estimators=50, random_state=0; total time=   0.4s
# [CV] END learning_rate=0.75, loss=exponential, n_estimators=50, random_state=0; total time=   0.4s
# [CV] END learning_rate=0.75, loss=exponential, n_estimators=50, random_state=1; total time=   0.4s
# [CV] END learning_rate=0.75, loss=exponential, n_estimators=50, random_state=1; total time=   0.4s
# [CV] END learning_rate=0.75, loss=exponential, n_estimators=50, random_state=1; total time=   0.4s
# [CV] END learning_rate=0.75, loss=exponential, n_estimators=50, random_state=2; total time=   0.4s
# [CV] END learning_rate=0.75, loss=exponential, n_estimators=50, random_state=2; total time=   0.4s
# [CV] END learning_rate=0.75, loss=exponential, n_estimators=50, random_state=2; total time=   0.4s
# [CV] END learning_rate=0.75, loss=exponential, n_estimators=60, random_state=0; total time=   0.5s
# [CV] END learning_rate=0.75, loss=exponential, n_estimators=60, random_state=0; total time=   0.5s
# [CV] END learning_rate=0.75, loss=exponential, n_estimators=60, random_state=0; total time=   0.5s
# [CV] END learning_rate=0.75, loss=exponential, n_estimators=60, random_state=1; total time=   0.5s
# [CV] END learning_rate=0.75, loss=exponential, n_estimators=60, random_state=1; total time=   0.5s
# [CV] END learning_rate=0.75, loss=exponential, n_estimators=60, random_state=1; total time=   0.5s
# [CV] END learning_rate=0.75, loss=exponential, n_estimators=60, random_state=2; total time=   0.5s
# [CV] END learning_rate=0.75, loss=exponential, n_estimators=60, random_state=2; total time=   0.5s
# [CV] END learning_rate=0.75, loss=exponential, n_estimators=60, random_state=2; total time=   0.5s
# GridSearchCV(cv=3, estimator=AdaBoostRegressor(),
#              param_grid={'learning_rate': [1.0, 0.75],
#                          'loss': ['linear', 'square', 'exponential'],
#                          'n_estimators': [50, 60], 'random_state': [0, 1, 2]},
#              scoring='roc_auc', verbose=2)

# %%
# BEST HYPER PARAMETER
rf_grid.best_params_
# Out:
# {'learning_rate': 1.0, 'loss': 'linear', 'n_estimators': 50, 'random_state': 0}

# %%
# USING BEST HYPER PARAMENTER OM THE MODEL
adr = AdaBoostRegressor(n_estimators=50, learning_rate=0.1, loss='linear', random_state= 0)

# %%
#  MODEL FITIING ON TRAIN DATASET
adr.fit(X_train, Y_train)
# Out:
# AdaBoostRegressor(learning_rate=0.1, random_state=0)

# %%
# PREDICTING X_TEST
y_pred = adr.predict(X_test)

# %%
#  MODEL FITIING ON TRAIn DATASET
adr.score(X_train, Y_train)
# Out:
# 0.6474924743563113

# %%
#  MODEL FITIING ON TEST DATASET
adr.score(X_test, Y_test)
# Out:
# 0.6375309010523563

# %%
# R_SQUARED
r2_score(Y_test, y_pred)
# Out:
# 0.6375309010523563

# %%
# ADJUSTED R-SQURED , MEAN SQUARED ERROR, ROOT MEAN SQUARED ERROR
print("Adjusted R2 : ",1-(1-r2_score((Y_test), (y_pred)))*((X_test.shape[0]-1)/(X_test.shape[0]-X_test.shape[1]-1)))
MSE  = mean_squared_error(Y_test, y_pred)
print("MSE :" , MSE)
RMSE = np.sqrt(MSE)
print("RMSE :" ,RMSE)
# Out:
# Adjusted R2 :  0.6348620075488303
# MSE : 148320.13904533724
# RMSE : 385.12353738162676

# %%
# PLOTTING FIRST 50 Y_TEST AND Y_PRED
plt.figure(figsize=(15,10))
plt.plot(np.array(Y_test[:50]), color = "orange")
plt.plot(y_pred[:50], color = "red")
plt.title("AdaBoostRegressor")
plt.legend(["Predicted","Actual"])
plt.show()

# %% [markdown]
# GradientBoostingRegressor

# %%
# IMPORTING GradientBoostingRegressor
from sklearn.ensemble import GradientBoostingRegressor

# %%
# PERFORMING HYPERPARAMETER TUNNING AND FITTING THE TRAIN DATASET 
rf_grid = GridSearchCV( GradientBoostingRegressor(),
                       param_grid ={
    "learning_rate": [0.001, 0.1],
    "min_samples_split": [5,2,6],
    "min_samples_leaf": [5,6,7],
    "max_depth":[8,9,10],
    "max_features":["auto"],
    "criterion": ["friedman_mse"],
    "n_estimators":[50]
    }, cv=5
                       , verbose=2, scoring='roc_auc')
rf_grid.fit(X_train,Y_train)
# Out:
# Fitting 5 folds for each of 54 candidates, totalling 270 fits
# [CV] END criterion=friedman_mse, learning_rate=0.001, max_depth=8, max_features=auto, min_samples_leaf=5, min_samples_split=5, n_estimators=50; total time=   1.0s
# [CV] END criterion=friedman_mse, learning_rate=0.001, max_depth=8, max_features=auto, min_samples_leaf=5, min_samples_split=5, n_estimators=50; total time=   0.9s
# [CV] END criterion=friedman_mse, learning_rate=0.001, max_depth=8, max_features=auto, min_samples_leaf=5, min_samples_split=5, n_estimators=50; total time=   0.9s
# [CV] END criterion=friedman_mse, learning_rate=0.001, max_depth=8, max_features=auto, min_samples_leaf=5, min_samples_split=5, n_estimators=50; total time=   0.9s
# [CV] END criterion=friedman_mse, learning_rate=0.001, max_depth=8, max_features=auto, min_samples_leaf=5, min_samples_split=5, n_estimators=50; total time=   0.9s
# [CV] END criterion=friedman_mse, learning_rate=0.001, max_depth=8, max_features=auto, min_samples_leaf=5, min_samples_split=2, n_estimators=50; total time=   0.9s
# [CV] END criterion=friedman_mse, learning_rate=0.001, max_depth=8, max_features=auto, min_samples_leaf=5, min_samples_split=2, n_estimators=50; total time=   0.9s
# [CV] END criterion=friedman_mse, learning_rate=0.001, max_depth=8, max_features=auto, min_samples_leaf=5, min_samples_split=2, n_estimators=50; total time=   0.9s
# [CV] END criterion=friedman_mse, learning_rate=0.001, max_depth=8, max_features=auto, min_samples_leaf=5, min_samples_split=2, n_estimators=50; total time=   0.9s
# [CV] END criterion=friedman_mse, learning_rate=0.001, max_depth=8, max_features=auto, min_samples_leaf=5, min_samples_split=2, n_estimators=50; total time=   0.9s
# [CV] END criterion=friedman_mse, learning_rate=0.001, max_depth=8, max_features=auto, min_samples_leaf=5, min_samples_split=6, n_estimators=50; total time=   0.9s
# [CV] END criterion=friedman_mse, learning_rate=0.001, max_depth=8, max_features=auto, min_samples_leaf=5, min_samples_split=6, n_estimators=50; total time=   0.9s
# [CV] END criterion=friedman_mse, learning_rate=0.001, max_depth=8, max_features=auto, min_samples_leaf=5, min_samples_split=6, n_estimators=50; total time=   0.9s
# [CV] END criterion=friedman_mse, learning_rate=0.001, max_depth=8, max_features=auto, min_samples_leaf=5, min_samples_split=6, n_estimators=50; total time=   0.9s
# [CV] END criterion=friedman_mse, learning_rate=0.001, max_depth=8, max_features=auto, min_samples_leaf=5, min_samples_split=6, n_estimators=50; total time=   0.9s
# [CV] END criterion=friedman_mse, learning_rate=0.001, max_depth=8, max_features=auto, min_samples_leaf=6, min_samples_split=5, n_estimators=50; total time=   0.9s
# [CV] END criterion=friedman_mse, learning_rate=0.001, max_depth=8, max_features=auto, min_samples_leaf=6, min_samples_split=5, n_estimators=50; total time=   0.9s
# [CV] END criterion=friedman_mse, learning_rate=0.001, max_depth=8, max_features=auto, min_samples_leaf=6, min_samples_split=5, n_estimators=50; total time=   0.9s
# [CV] END criterion=friedman_mse, learning_rate=0.001, max_depth=8, max_features=auto, min_samples_leaf=6, min_samples_split=5, n_estimators=50; total time=   0.9s
# [CV] END criterion=friedman_mse, learning_rate=0.001, max_depth=8, max_features=auto, min_samples_leaf=6, min_samples_split=5, n_estimators=50; total time=   0.9s
# [CV] END criterion=friedman_mse, learning_rate=0.001, max_depth=8, max_features=auto, min_samples_leaf=6, min_samples_split=2, n_estimators=50; total time=   0.9s
# [CV] END criterion=friedman_mse, learning_rate=0.001, max_depth=8, max_features=auto, min_samples_leaf=6, min_samples_split=2, n_estimators=50; total time=   0.9s
# [CV] END criterion=friedman_mse, learning_rate=0.001, max_depth=8, max_features=auto, min_samples_leaf=6, min_samples_split=2, n_estimators=50; total time=   0.9s
# [CV] END criterion=friedman_mse, learning_rate=0.001, max_depth=8, max_features=auto, min_samples_leaf=6, min_samples_split=2, n_estimators=50; total time=   0.9s
# [CV] END criterion=friedman_mse, learning_rate=0.001, max_depth=8, max_features=auto, min_samples_leaf=6, min_samples_split=2, n_estimators=50; total time=   0.9s
# [CV] END criterion=friedman_mse, learning_rate=0.001, max_depth=8, max_features=auto, min_samples_leaf=6, min_samples_split=6, n_estimators=50; total time=   0.9s
# [CV] END criterion=friedman_mse, learning_rate=0.001, max_depth=8, max_features=auto, min_samples_leaf=6, min_samples_split=6, n_estimators=50; total time=   0.9s
# [CV] END criterion=friedman_mse, learning_rate=0.001, max_depth=8, max_features=auto, min_samples_leaf=6, min_samples_split=6, n_estimators=50; total time=   0.9s
# [CV] END criterion=friedman_mse, learning_rate=0.001, max_depth=8, max_features=auto, min_samples_leaf=6, min_samples_split=6, n_estimators=50; total time=   0.9s
# [CV] END criterion=friedman_mse, learning_rate=0.001, max_depth=8, max_features=auto, min_samples_leaf=6, min_samples_split=6, n_estimators=50; total time=   0.9s
# [CV] END criterion=friedman_mse, learning_rate=0.001, max_depth=8, max_features=auto, min_samples_leaf=7, min_samples_split=5, n_estimators=50; total time=   0.9s
# [CV] END criterion=friedman_mse, learning_rate=0.001, max_depth=8, max_features=auto, min_samples_leaf=7, min_samples_split=5, n_estimators=50; total time=   0.9s
# [CV] END criterion=friedman_mse, learning_rate=0.001, max_depth=8, max_features=auto, min_samples_leaf=7, min_samples_split=5, n_estimators=50; total time=   0.9s
# [CV] END criterion=friedman_mse, learning_rate=0.001, max_depth=8, max_features=auto, min_samples_leaf=7, min_samples_split=5, n_estimators=50; total time=   0.9s
# [CV] END criterion=friedman_mse, learning_rate=0.001, max_depth=8, max_features=auto, min_samples_leaf=7, min_samples_split=5, n_estimators=50; total time=   0.9s
# [CV] END criterion=friedman_mse, learning_rate=0.001, max_depth=8, max_features=auto, min_samples_leaf=7, min_samples_split=2, n_estimators=50; total time=   0.9s
# [CV] END criterion=friedman_mse, learning_rate=0.001, max_depth=8, max_features=auto, min_samples_leaf=7, min_samples_split=2, n_estimators=50; total time=   0.9s
# [CV] END criterion=friedman_mse, learning_rate=0.001, max_depth=8, max_features=auto, min_samples_leaf=7, min_samples_split=2, n_estimators=50; total time=   0.9s
# [CV] END criterion=friedman_mse, learning_rate=0.001, max_depth=8, max_features=auto, min_samples_leaf=7, min_samples_split=2, n_estimators=50; total time=   0.9s
# [CV] END criterion=friedman_mse, learning_rate=0.001, max_depth=8, max_features=auto, min_samples_leaf=7, min_samples_split=2, n_estimators=50; total time=   0.9s
# [CV] END criterion=friedman_mse, learning_rate=0.001, max_depth=8, max_features=auto, min_samples_leaf=7, min_samples_split=6, n_estimators=50; total time=   0.9s
# [CV] END criterion=friedman_mse, learning_rate=0.001, max_depth=8, max_features=auto, min_samples_leaf=7, min_samples_split=6, n_estimators=50; total time=   0.9s
# [CV] END criterion=friedman_mse, learning_rate=0.001, max_depth=8, max_features=auto, min_samples_leaf=7, min_samples_split=6, n_estimators=50; total time=   0.9s
# [CV] END criterion=friedman_mse, learning_rate=0.001, max_depth=8, max_features=auto, min_samples_leaf=7, min_samples_split=6, n_estimators=50; total time=   0.9s
# [CV] END criterion=friedman_mse, learning_rate=0.001, max_depth=8, max_features=auto, min_samples_leaf=7, min_samples_split=6, n_estimators=50; total time=   0.9s
# [CV] END criterion=friedman_mse, learning_rate=0.001, max_depth=9, max_features=auto, min_samples_leaf=5, min_samples_split=5, n_estimators=50; total time=   1.0s
# [CV] END criterion=friedman_mse, learning_rate=0.001, max_depth=9, max_features=auto, min_samples_leaf=5, min_samples_split=5, n_estimators=50; total time=   1.0s
# [CV] END criterion=friedman_mse, learning_rate=0.001, max_depth=9, max_features=auto, min_samples_leaf=5, min_samples_split=5, n_estimators=50; total time=   1.0s
# [CV] END criterion=friedman_mse, learning_rate=0.001, max_depth=9, max_features=auto, min_samples_leaf=5, min_samples_split=5, n_estimators=50; total time=   1.0s
# [CV] END criterion=friedman_mse, learning_rate=0.001, max_depth=9, max_features=auto, min_samples_leaf=5, min_samples_split=5, n_estimators=50; total time=   1.0s
# [CV] END criterion=friedman_mse, learning_rate=0.001, max_depth=9, max_features=auto, min_samples_leaf=5, min_samples_split=2, n_estimators=50; total time=   1.0s
# [CV] END criterion=friedman_mse, learning_rate=0.001, max_depth=9, max_features=auto, min_samples_leaf=5, min_samples_split=2, n_estimators=50; total time=   1.0s
# [CV] END criterion=friedman_mse, learning_rate=0.001, max_depth=9, max_features=auto, min_samples_leaf=5, min_samples_split=2, n_estimators=50; total time=   1.0s
# [CV] END criterion=friedman_mse, learning_rate=0.001, max_depth=9, max_features=auto, min_samples_leaf=5, min_samples_split=2, n_estimators=50; total time=   1.0s
# [CV] END criterion=friedman_mse, learning_rate=0.001, max_depth=9, max_features=auto, min_samples_leaf=5, min_samples_split=2, n_estimators=50; total time=   1.0s
# [CV] END criterion=friedman_mse, learning_rate=0.001, max_depth=9, max_features=auto, min_samples_leaf=5, min_samples_split=6, n_estimators=50; total time=   1.0s
# [CV] END criterion=friedman_mse, learning_rate=0.001, max_depth=9, max_features=auto, min_samples_leaf=5, min_samples_split=6, n_estimators=50; total time=   1.0s
# [CV] END criterion=friedman_mse, learning_rate=0.001, max_depth=9, max_features=auto, min_samples_leaf=5, min_samples_split=6, n_estimators=50; total time=   1.0s
# [CV] END criterion=friedman_mse, learning_rate=0.001, max_depth=9, max_features=auto, min_samples_leaf=5, min_samples_split=6, n_estimators=50; total time=   1.0s
# [CV] END criterion=friedman_mse, learning_rate=0.001, max_depth=9, max_features=auto, min_samples_leaf=5, min_samples_split=6, n_estimators=50; total time=   1.0s
# [CV] END criterion=friedman_mse, learning_rate=0.001, max_depth=9, max_features=auto, min_samples_leaf=6, min_samples_split=5, n_estimators=50; total time=   1.0s
# [CV] END criterion=friedman_mse, learning_rate=0.001, max_depth=9, max_features=auto, min_samples_leaf=6, min_samples_split=5, n_estimators=50; total time=   1.0s
# [CV] END criterion=friedman_mse, learning_rate=0.001, max_depth=9, max_features=auto, min_samples_leaf=6, min_samples_split=5, n_estimators=50; total time=   1.0s
# [CV] END criterion=friedman_mse, learning_rate=0.001, max_depth=9, max_features=auto, min_samples_leaf=6, min_samples_split=5, n_estimators=50; total time=   1.0s
# [CV] END criterion=friedman_mse, learning_rate=0.001, max_depth=9, max_features=auto, min_samples_leaf=6, min_samples_split=5, n_estimators=50; total time=   1.0s
# [CV] END criterion=friedman_mse, learning_rate=0.001, max_depth=9, max_features=auto, min_samples_leaf=6, min_samples_split=2, n_estimators=50; total time=   1.0s
# [CV] END criterion=friedman_mse, learning_rate=0.001, max_depth=9, max_features=auto, min_samples_leaf=6, min_samples_split=2, n_estimators=50; total time=   1.0s
# [CV] END criterion=friedman_mse, learning_rate=0.001, max_depth=9, max_features=auto, min_samples_leaf=6, min_samples_split=2, n_estimators=50; total time=   1.0s
# [CV] END criterion=friedman_mse, learning_rate=0.001, max_depth=9, max_features=auto, min_samples_leaf=6, min_samples_split=2, n_estimators=50; total time=   1.0s
# [CV] END criterion=friedman_mse, learning_rate=0.001, max_depth=9, max_features=auto, min_samples_leaf=6, min_samples_split=2, n_estimators=50; total time=   1.0s
# [CV] END criterion=friedman_mse, learning_rate=0.001, max_depth=9, max_features=auto, min_samples_leaf=6, min_samples_split=6, n_estimators=50; total time=   1.0s
# [CV] END criterion=friedman_mse, learning_rate=0.001, max_depth=9, max_features=auto, min_samples_leaf=6, min_samples_split=6, n_estimators=50; total time=   1.0s
# [CV] END criterion=friedman_mse, learning_rate=0.001, max_depth=9, max_features=auto, min_samples_leaf=6, min_samples_split=6, n_estimators=50; total time=   1.0s
# [CV] END criterion=friedman_mse, learning_rate=0.001, max_depth=9, max_features=auto, min_samples_leaf=6, min_samples_split=6, n_estimators=50; total time=   1.0s
# [CV] END criterion=friedman_mse, learning_rate=0.001, max_depth=9, max_features=auto, min_samples_leaf=6, min_samples_split=6, n_estimators=50; total time=   1.0s
# [CV] END criterion=friedman_mse, learning_rate=0.001, max_depth=9, max_features=auto, min_samples_leaf=7, min_samples_split=5, n_estimators=50; total time=   1.0s
# [CV] END criterion=friedman_mse, learning_rate=0.001, max_depth=9, max_features=auto, min_samples_leaf=7, min_samples_split=5, n_estimators=50; total time=   1.0s
# [CV] END criterion=friedman_mse, learning_rate=0.001, max_depth=9, max_features=auto, min_samples_leaf=7, min_samples_split=5, n_estimators=50; total time=   1.0s
# [CV] END criterion=friedman_mse, learning_rate=0.001, max_depth=9, max_features=auto, min_samples_leaf=7, min_samples_split=5, n_estimators=50; total time=   1.0s
# [CV] END criterion=friedman_mse, learning_rate=0.001, max_depth=9, max_features=auto, min_samples_leaf=7, min_samples_split=5, n_estimators=50; total time=   1.0s
# [CV] END criterion=friedman_mse, learning_rate=0.001, max_depth=9, max_features=auto, min_samples_leaf=7, min_samples_split=2, n_estimators=50; total time=   1.0s
# [CV] END criterion=friedman_mse, learning_rate=0.001, max_depth=9, max_features=auto, min_samples_leaf=7, min_samples_split=2, n_estimators=50; total time=   1.0s
# [CV] END criterion=friedman_mse, learning_rate=0.001, max_depth=9, max_features=auto, min_samples_leaf=7, min_samples_split=2, n_estimators=50; total time=   1.0s
# [CV] END criterion=friedman_mse, learning_rate=0.001, max_depth=9, max_features=auto, min_samples_leaf=7, min_samples_split=2, n_estimators=50; total time=   1.0s
# [CV] END criterion=friedman_mse, learning_rate=0.001, max_depth=9, max_features=auto, min_samples_leaf=7, min_samples_split=2, n_estimators=50; total time=   1.0s
# [CV] END criterion=friedman_mse, learning_rate=0.001, max_depth=9, max_features=auto, min_samples_leaf=7, min_samples_split=6, n_estimators=50; total time=   1.0s
# [CV] END criterion=friedman_mse, learning_rate=0.001, max_depth=9, max_features=auto, min_samples_leaf=7, min_samples_split=6, n_estimators=50; total time=   1.0s
# [CV] END criterion=friedman_mse, learning_rate=0.001, max_depth=9, max_features=auto, min_samples_leaf=7, min_samples_split=6, n_estimators=50; total time=   1.0s
# [CV] END criterion=friedman_mse, learning_rate=0.001, max_depth=9, max_features=auto, min_samples_leaf=7, min_samples_split=6, n_estimators=50; total time=   1.0s
# [CV] END criterion=friedman_mse, learning_rate=0.001, max_depth=9, max_features=auto, min_samples_leaf=7, min_samples_split=6, n_estimators=50; total time=   1.0s
# [CV] END criterion=friedman_mse, learning_rate=0.001, max_depth=10, max_features=auto, min_samples_leaf=5, min_samples_split=5, n_estimators=50; total time=   1.1s
# [CV] END criterion=friedman_mse, learning_rate=0.001, max_depth=10, max_features=auto, min_samples_leaf=5, min_samples_split=5, n_estimators=50; total time=   1.1s
# [CV] END criterion=friedman_mse, learning_rate=0.001, max_depth=10, max_features=auto, min_samples_leaf=5, min_samples_split=5, n_estimators=50; total time=   1.1s
# [CV] END criterion=friedman_mse, learning_rate=0.001, max_depth=10, max_features=auto, min_samples_leaf=5, min_samples_split=5, n_estimators=50; total time=   1.1s
# [CV] END criterion=friedman_mse, learning_rate=0.001, max_depth=10, max_features=auto, min_samples_leaf=5, min_samples_split=5, n_estimators=50; total time=   1.1s
# [CV] END criterion=friedman_mse, learning_rate=0.001, max_depth=10, max_features=auto, min_samples_leaf=5, min_samples_split=2, n_estimators=50; total time=   1.1s
# [CV] END criterion=friedman_mse, learning_rate=0.001, max_depth=10, max_features=auto, min_samples_leaf=5, min_samples_split=2, n_estimators=50; total time=   1.1s
# [CV] END criterion=friedman_mse, learning_rate=0.001, max_depth=10, max_features=auto, min_samples_leaf=5, min_samples_split=2, n_estimators=50; total time=   1.1s
# [CV] END criterion=friedman_mse, learning_rate=0.001, max_depth=10, max_features=auto, min_samples_leaf=5, min_samples_split=2, n_estimators=50; total time=   1.1s
# [CV] END criterion=friedman_mse, learning_rate=0.001, max_depth=10, max_features=auto, min_samples_leaf=5, min_samples_split=2, n_estimators=50; total time=   1.1s
# [CV] END criterion=friedman_mse, learning_rate=0.001, max_depth=10, max_features=auto, min_samples_leaf=5, min_samples_split=6, n_estimators=50; total time=   1.1s
# [CV] END criterion=friedman_mse, learning_rate=0.001, max_depth=10, max_features=auto, min_samples_leaf=5, min_samples_split=6, n_estimators=50; total time=   1.1s
# [CV] END criterion=friedman_mse, learning_rate=0.001, max_depth=10, max_features=auto, min_samples_leaf=5, min_samples_split=6, n_estimators=50; total time=   1.1s
# [CV] END criterion=friedman_mse, learning_rate=0.001, max_depth=10, max_features=auto, min_samples_leaf=5, min_samples_split=6, n_estimators=50; total time=   1.1s
# [CV] END criterion=friedman_mse, learning_rate=0.001, max_depth=10, max_features=auto, min_samples_leaf=5, min_samples_split=6, n_estimators=50; total time=   1.1s
# [CV] END criterion=friedman_mse, learning_rate=0.001, max_depth=10, max_features=auto, min_samples_leaf=6, min_samples_split=5, n_estimators=50; total time=   1.1s
# [CV] END criterion=friedman_mse, learning_rate=0.001, max_depth=10, max_features=auto, min_samples_leaf=6, min_samples_split=5, n_estimators=50; total time=   1.1s
# [CV] END criterion=friedman_mse, learning_rate=0.001, max_depth=10, max_features=auto, min_samples_leaf=6, min_samples_split=5, n_estimators=50; total time=   1.1s
# [CV] END criterion=friedman_mse, learning_rate=0.001, max_depth=10, max_features=auto, min_samples_leaf=6, min_samples_split=5, n_estimators=50; total time=   1.1s
# [CV] END criterion=friedman_mse, learning_rate=0.001, max_depth=10, max_features=auto, min_samples_leaf=6, min_samples_split=5, n_estimators=50; total time=   1.1s
# [CV] END criterion=friedman_mse, learning_rate=0.001, max_depth=10, max_features=auto, min_samples_leaf=6, min_samples_split=2, n_estimators=50; total time=   1.1s
# [CV] END criterion=friedman_mse, learning_rate=0.001, max_depth=10, max_features=auto, min_samples_leaf=6, min_samples_split=2, n_estimators=50; total time=   1.1s
# [CV] END criterion=friedman_mse, learning_rate=0.001, max_depth=10, max_features=auto, min_samples_leaf=6, min_samples_split=2, n_estimators=50; total time=   1.1s
# [CV] END criterion=friedman_mse, learning_rate=0.001, max_depth=10, max_features=auto, min_samples_leaf=6, min_samples_split=2, n_estimators=50; total time=   1.1s
# [CV] END criterion=friedman_mse, learning_rate=0.001, max_depth=10, max_features=auto, min_samples_leaf=6, min_samples_split=2, n_estimators=50; total time=   1.1s
# [CV] END criterion=friedman_mse, learning_rate=0.001, max_depth=10, max_features=auto, min_samples_leaf=6, min_samples_split=6, n_estimators=50; total time=   1.1s
# [CV] END criterion=friedman_mse, learning_rate=0.001, max_depth=10, max_features=auto, min_samples_leaf=6, min_samples_split=6, n_estimators=50; total time=   1.1s
# [CV] END criterion=friedman_mse, learning_rate=0.001, max_depth=10, max_features=auto, min_samples_leaf=6, min_samples_split=6, n_estimators=50; total time=   1.1s
# [CV] END criterion=friedman_mse, learning_rate=0.001, max_depth=10, max_features=auto, min_samples_leaf=6, min_samples_split=6, n_estimators=50; total time=   1.1s
# [CV] END criterion=friedman_mse, learning_rate=0.001, max_depth=10, max_features=auto, min_samples_leaf=6, min_samples_split=6, n_estimators=50; total time=   1.1s
# [CV] END criterion=friedman_mse, learning_rate=0.001, max_depth=10, max_features=auto, min_samples_leaf=7, min_samples_split=5, n_estimators=50; total time=   1.1s
# [CV] END criterion=friedman_mse, learning_rate=0.001, max_depth=10, max_features=auto, min_samples_leaf=7, min_samples_split=5, n_estimators=50; total time=   1.1s
# [CV] END criterion=friedman_mse, learning_rate=0.001, max_depth=10, max_features=auto, min_samples_leaf=7, min_samples_split=5, n_estimators=50; total time=   1.1s
# [CV] END criterion=friedman_mse, learning_rate=0.001, max_depth=10, max_features=auto, min_samples_leaf=7, min_samples_split=5, n_estimators=50; total time=   1.1s
# [CV] END criterion=friedman_mse, learning_rate=0.001, max_depth=10, max_features=auto, min_samples_leaf=7, min_samples_split=5, n_estimators=50; total time=   1.1s
# [CV] END criterion=friedman_mse, learning_rate=0.001, max_depth=10, max_features=auto, min_samples_leaf=7, min_samples_split=2, n_estimators=50; total time=   1.1s
# [CV] END criterion=friedman_mse, learning_rate=0.001, max_depth=10, max_features=auto, min_samples_leaf=7, min_samples_split=2, n_estimators=50; total time=   1.1s
# [CV] END criterion=friedman_mse, learning_rate=0.001, max_depth=10, max_features=auto, min_samples_leaf=7, min_samples_split=2, n_estimators=50; total time=   1.1s
# [CV] END criterion=friedman_mse, learning_rate=0.001, max_depth=10, max_features=auto, min_samples_leaf=7, min_samples_split=2, n_estimators=50; total time=   1.1s
# [CV] END criterion=friedman_mse, learning_rate=0.001, max_depth=10, max_features=auto, min_samples_leaf=7, min_samples_split=2, n_estimators=50; total time=   1.1s
# [CV] END criterion=friedman_mse, learning_rate=0.001, max_depth=10, max_features=auto, min_samples_leaf=7, min_samples_split=6, n_estimators=50; total time=   1.1s
# [CV] END criterion=friedman_mse, learning_rate=0.001, max_depth=10, max_features=auto, min_samples_leaf=7, min_samples_split=6, n_estimators=50; total time=   1.1s
# [CV] END criterion=friedman_mse, learning_rate=0.001, max_depth=10, max_features=auto, min_samples_leaf=7, min_samples_split=6, n_estimators=50; total time=   1.1s
# [CV] END criterion=friedman_mse, learning_rate=0.001, max_depth=10, max_features=auto, min_samples_leaf=7, min_samples_split=6, n_estimators=50; total time=   1.1s
# [CV] END criterion=friedman_mse, learning_rate=0.001, max_depth=10, max_features=auto, min_samples_leaf=7, min_samples_split=6, n_estimators=50; total time=   1.1s
# [CV] END criterion=friedman_mse, learning_rate=0.1, max_depth=8, max_features=auto, min_samples_leaf=5, min_samples_split=5, n_estimators=50; total time=   0.9s
# [CV] END criterion=friedman_mse, learning_rate=0.1, max_depth=8, max_features=auto, min_samples_leaf=5, min_samples_split=5, n_estimators=50; total time=   0.9s
# [CV] END criterion=friedman_mse, learning_rate=0.1, max_depth=8, max_features=auto, min_samples_leaf=5, min_samples_split=5, n_estimators=50; total time=   0.9s
# [CV] END criterion=friedman_mse, learning_rate=0.1, max_depth=8, max_features=auto, min_samples_leaf=5, min_samples_split=5, n_estimators=50; total time=   0.9s
# [CV] END criterion=friedman_mse, learning_rate=0.1, max_depth=8, max_features=auto, min_samples_leaf=5, min_samples_split=5, n_estimators=50; total time=   0.9s
# [CV] END criterion=friedman_mse, learning_rate=0.1, max_depth=8, max_features=auto, min_samples_leaf=5, min_samples_split=2, n_estimators=50; total time=   0.9s
# [CV] END criterion=friedman_mse, learning_rate=0.1, max_depth=8, max_features=auto, min_samples_leaf=5, min_samples_split=2, n_estimators=50; total time=   0.9s
# [CV] END criterion=friedman_mse, learning_rate=0.1, max_depth=8, max_features=auto, min_samples_leaf=5, min_samples_split=2, n_estimators=50; total time=   0.9s
# [CV] END criterion=friedman_mse, learning_rate=0.1, max_depth=8, max_features=auto, min_samples_leaf=5, min_samples_split=2, n_estimators=50; total time=   0.9s
# [CV] END criterion=friedman_mse, learning_rate=0.1, max_depth=8, max_features=auto, min_samples_leaf=5, min_samples_split=2, n_estimators=50; total time=   0.9s
# [CV] END criterion=friedman_mse, learning_rate=0.1, max_depth=8, max_features=auto, min_samples_leaf=5, min_samples_split=6, n_estimators=50; total time=   0.9s
# [CV] END criterion=friedman_mse, learning_rate=0.1, max_depth=8, max_features=auto, min_samples_leaf=5, min_samples_split=6, n_estimators=50; total time=   0.9s
# [CV] END criterion=friedman_mse, learning_rate=0.1, max_depth=8, max_features=auto, min_samples_leaf=5, min_samples_split=6, n_estimators=50; total time=   0.9s
# [CV] END criterion=friedman_mse, learning_rate=0.1, max_depth=8, max_features=auto, min_samples_leaf=5, min_samples_split=6, n_estimators=50; total time=   0.9s
# [CV] END criterion=friedman_mse, learning_rate=0.1, max_depth=8, max_features=auto, min_samples_leaf=5, min_samples_split=6, n_estimators=50; total time=   0.9s
# [CV] END criterion=friedman_mse, learning_rate=0.1, max_depth=8, max_features=auto, min_samples_leaf=6, min_samples_split=5, n_estimators=50; total time=   0.9s
# [CV] END criterion=friedman_mse, learning_rate=0.1, max_depth=8, max_features=auto, min_samples_leaf=6, min_samples_split=5, n_estimators=50; total time=   0.9s
# [CV] END criterion=friedman_mse, learning_rate=0.1, max_depth=8, max_features=auto, min_samples_leaf=6, min_samples_split=5, n_estimators=50; total time=   0.9s
# [CV] END criterion=friedman_mse, learning_rate=0.1, max_depth=8, max_features=auto, min_samples_leaf=6, min_samples_split=5, n_estimators=50; total time=   0.9s
# [CV] END criterion=friedman_mse, learning_rate=0.1, max_depth=8, max_features=auto, min_samples_leaf=6, min_samples_split=5, n_estimators=50; total time=   0.9s
# [CV] END criterion=friedman_mse, learning_rate=0.1, max_depth=8, max_features=auto, min_samples_leaf=6, min_samples_split=2, n_estimators=50; total time=   0.9s
# [CV] END criterion=friedman_mse, learning_rate=0.1, max_depth=8, max_features=auto, min_samples_leaf=6, min_samples_split=2, n_estimators=50; total time=   0.9s
# [CV] END criterion=friedman_mse, learning_rate=0.1, max_depth=8, max_features=auto, min_samples_leaf=6, min_samples_split=2, n_estimators=50; total time=   0.9s
# [CV] END criterion=friedman_mse, learning_rate=0.1, max_depth=8, max_features=auto, min_samples_leaf=6, min_samples_split=2, n_estimators=50; total time=   0.9s
# [CV] END criterion=friedman_mse, learning_rate=0.1, max_depth=8, max_features=auto, min_samples_leaf=6, min_samples_split=2, n_estimators=50; total time=   1.0s
# [CV] END criterion=friedman_mse, learning_rate=0.1, max_depth=8, max_features=auto, min_samples_leaf=6, min_samples_split=6, n_estimators=50; total time=   0.9s
# [CV] END criterion=friedman_mse, learning_rate=0.1, max_depth=8, max_features=auto, min_samples_leaf=6, min_samples_split=6, n_estimators=50; total time=   0.9s
# [CV] END criterion=friedman_mse, learning_rate=0.1, max_depth=8, max_features=auto, min_samples_leaf=6, min_samples_split=6, n_estimators=50; total time=   0.9s
# [CV] END criterion=friedman_mse, learning_rate=0.1, max_depth=8, max_features=auto, min_samples_leaf=6, min_samples_split=6, n_estimators=50; total time=   0.9s
# [CV] END criterion=friedman_mse, learning_rate=0.1, max_depth=8, max_features=auto, min_samples_leaf=6, min_samples_split=6, n_estimators=50; total time=   1.0s
# [CV] END criterion=friedman_mse, learning_rate=0.1, max_depth=8, max_features=auto, min_samples_leaf=7, min_samples_split=5, n_estimators=50; total time=   0.9s
# [CV] END criterion=friedman_mse, learning_rate=0.1, max_depth=8, max_features=auto, min_samples_leaf=7, min_samples_split=5, n_estimators=50; total time=   0.9s
# [CV] END criterion=friedman_mse, learning_rate=0.1, max_depth=8, max_features=auto, min_samples_leaf=7, min_samples_split=5, n_estimators=50; total time=   0.9s
# [CV] END criterion=friedman_mse, learning_rate=0.1, max_depth=8, max_features=auto, min_samples_leaf=7, min_samples_split=5, n_estimators=50; total time=   0.9s
# [CV] END criterion=friedman_mse, learning_rate=0.1, max_depth=8, max_features=auto, min_samples_leaf=7, min_samples_split=5, n_estimators=50; total time=   0.9s
# [CV] END criterion=friedman_mse, learning_rate=0.1, max_depth=8, max_features=auto, min_samples_leaf=7, min_samples_split=2, n_estimators=50; total time=   0.9s
# [CV] END criterion=friedman_mse, learning_rate=0.1, max_depth=8, max_features=auto, min_samples_leaf=7, min_samples_split=2, n_estimators=50; total time=   0.9s
# [CV] END criterion=friedman_mse, learning_rate=0.1, max_depth=8, max_features=auto, min_samples_leaf=7, min_samples_split=2, n_estimators=50; total time=   0.9s
# [CV] END criterion=friedman_mse, learning_rate=0.1, max_depth=8, max_features=auto, min_samples_leaf=7, min_samples_split=2, n_estimators=50; total time=   0.9s
# [CV] END criterion=friedman_mse, learning_rate=0.1, max_depth=8, max_features=auto, min_samples_leaf=7, min_samples_split=2, n_estimators=50; total time=   0.9s
# [CV] END criterion=friedman_mse, learning_rate=0.1, max_depth=8, max_features=auto, min_samples_leaf=7, min_samples_split=6, n_estimators=50; total time=   0.9s
# [CV] END criterion=friedman_mse, learning_rate=0.1, max_depth=8, max_features=auto, min_samples_leaf=7, min_samples_split=6, n_estimators=50; total time=   0.9s
# [CV] END criterion=friedman_mse, learning_rate=0.1, max_depth=8, max_features=auto, min_samples_leaf=7, min_samples_split=6, n_estimators=50; total time=   0.9s
# [CV] END criterion=friedman_mse, learning_rate=0.1, max_depth=8, max_features=auto, min_samples_leaf=7, min_samples_split=6, n_estimators=50; total time=   0.9s
# [CV] END criterion=friedman_mse, learning_rate=0.1, max_depth=8, max_features=auto, min_samples_leaf=7, min_samples_split=6, n_estimators=50; total time=   0.9s
# [CV] END criterion=friedman_mse, learning_rate=0.1, max_depth=9, max_features=auto, min_samples_leaf=5, min_samples_split=5, n_estimators=50; total time=   1.0s
# [CV] END criterion=friedman_mse, learning_rate=0.1, max_depth=9, max_features=auto, min_samples_leaf=5, min_samples_split=5, n_estimators=50; total time=   1.0s
# [CV] END criterion=friedman_mse, learning_rate=0.1, max_depth=9, max_features=auto, min_samples_leaf=5, min_samples_split=5, n_estimators=50; total time=   1.0s
# [CV] END criterion=friedman_mse, learning_rate=0.1, max_depth=9, max_features=auto, min_samples_leaf=5, min_samples_split=5, n_estimators=50; total time=   1.0s
# [CV] END criterion=friedman_mse, learning_rate=0.1, max_depth=9, max_features=auto, min_samples_leaf=5, min_samples_split=5, n_estimators=50; total time=   1.0s
# [CV] END criterion=friedman_mse, learning_rate=0.1, max_depth=9, max_features=auto, min_samples_leaf=5, min_samples_split=2, n_estimators=50; total time=   1.0s
# [CV] END criterion=friedman_mse, learning_rate=0.1, max_depth=9, max_features=auto, min_samples_leaf=5, min_samples_split=2, n_estimators=50; total time=   1.0s
# [CV] END criterion=friedman_mse, learning_rate=0.1, max_depth=9, max_features=auto, min_samples_leaf=5, min_samples_split=2, n_estimators=50; total time=   1.0s
# [CV] END criterion=friedman_mse, learning_rate=0.1, max_depth=9, max_features=auto, min_samples_leaf=5, min_samples_split=2, n_estimators=50; total time=   1.0s
# [CV] END criterion=friedman_mse, learning_rate=0.1, max_depth=9, max_features=auto, min_samples_leaf=5, min_samples_split=2, n_estimators=50; total time=   1.0s
# [CV] END criterion=friedman_mse, learning_rate=0.1, max_depth=9, max_features=auto, min_samples_leaf=5, min_samples_split=6, n_estimators=50; total time=   1.0s
# [CV] END criterion=friedman_mse, learning_rate=0.1, max_depth=9, max_features=auto, min_samples_leaf=5, min_samples_split=6, n_estimators=50; total time=   1.0s
# [CV] END criterion=friedman_mse, learning_rate=0.1, max_depth=9, max_features=auto, min_samples_leaf=5, min_samples_split=6, n_estimators=50; total time=   1.0s
# [CV] END criterion=friedman_mse, learning_rate=0.1, max_depth=9, max_features=auto, min_samples_leaf=5, min_samples_split=6, n_estimators=50; total time=   1.0s
# [CV] END criterion=friedman_mse, learning_rate=0.1, max_depth=9, max_features=auto, min_samples_leaf=5, min_samples_split=6, n_estimators=50; total time=   1.0s
# [CV] END criterion=friedman_mse, learning_rate=0.1, max_depth=9, max_features=auto, min_samples_leaf=6, min_samples_split=5, n_estimators=50; total time=   1.0s
# [CV] END criterion=friedman_mse, learning_rate=0.1, max_depth=9, max_features=auto, min_samples_leaf=6, min_samples_split=5, n_estimators=50; total time=   1.0s
# [CV] END criterion=friedman_mse, learning_rate=0.1, max_depth=9, max_features=auto, min_samples_leaf=6, min_samples_split=5, n_estimators=50; total time=   1.0s
# [CV] END criterion=friedman_mse, learning_rate=0.1, max_depth=9, max_features=auto, min_samples_leaf=6, min_samples_split=5, n_estimators=50; total time=   1.0s
# [CV] END criterion=friedman_mse, learning_rate=0.1, max_depth=9, max_features=auto, min_samples_leaf=6, min_samples_split=5, n_estimators=50; total time=   1.0s
# [CV] END criterion=friedman_mse, learning_rate=0.1, max_depth=9, max_features=auto, min_samples_leaf=6, min_samples_split=2, n_estimators=50; total time=   1.0s
# [CV] END criterion=friedman_mse, learning_rate=0.1, max_depth=9, max_features=auto, min_samples_leaf=6, min_samples_split=2, n_estimators=50; total time=   1.0s
# [CV] END criterion=friedman_mse, learning_rate=0.1, max_depth=9, max_features=auto, min_samples_leaf=6, min_samples_split=2, n_estimators=50; total time=   1.0s
# [CV] END criterion=friedman_mse, learning_rate=0.1, max_depth=9, max_features=auto, min_samples_leaf=6, min_samples_split=2, n_estimators=50; total time=   1.0s
# [CV] END criterion=friedman_mse, learning_rate=0.1, max_depth=9, max_features=auto, min_samples_leaf=6, min_samples_split=2, n_estimators=50; total time=   1.0s
# [CV] END criterion=friedman_mse, learning_rate=0.1, max_depth=9, max_features=auto, min_samples_leaf=6, min_samples_split=6, n_estimators=50; total time=   1.0s
# [CV] END criterion=friedman_mse, learning_rate=0.1, max_depth=9, max_features=auto, min_samples_leaf=6, min_samples_split=6, n_estimators=50; total time=   1.0s
# [CV] END criterion=friedman_mse, learning_rate=0.1, max_depth=9, max_features=auto, min_samples_leaf=6, min_samples_split=6, n_estimators=50; total time=   1.0s
# [CV] END criterion=friedman_mse, learning_rate=0.1, max_depth=9, max_features=auto, min_samples_leaf=6, min_samples_split=6, n_estimators=50; total time=   1.0s
# [CV] END criterion=friedman_mse, learning_rate=0.1, max_depth=9, max_features=auto, min_samples_leaf=6, min_samples_split=6, n_estimators=50; total time=   1.0s
# [CV] END criterion=friedman_mse, learning_rate=0.1, max_depth=9, max_features=auto, min_samples_leaf=7, min_samples_split=5, n_estimators=50; total time=   1.0s
# [CV] END criterion=friedman_mse, learning_rate=0.1, max_depth=9, max_features=auto, min_samples_leaf=7, min_samples_split=5, n_estimators=50; total time=   1.0s
# [CV] END criterion=friedman_mse, learning_rate=0.1, max_depth=9, max_features=auto, min_samples_leaf=7, min_samples_split=5, n_estimators=50; total time=   1.0s
# [CV] END criterion=friedman_mse, learning_rate=0.1, max_depth=9, max_features=auto, min_samples_leaf=7, min_samples_split=5, n_estimators=50; total time=   1.0s
# [CV] END criterion=friedman_mse, learning_rate=0.1, max_depth=9, max_features=auto, min_samples_leaf=7, min_samples_split=5, n_estimators=50; total time=   1.0s
# [CV] END criterion=friedman_mse, learning_rate=0.1, max_depth=9, max_features=auto, min_samples_leaf=7, min_samples_split=2, n_estimators=50; total time=   1.0s
# [CV] END criterion=friedman_mse, learning_rate=0.1, max_depth=9, max_features=auto, min_samples_leaf=7, min_samples_split=2, n_estimators=50; total time=   1.0s
# [CV] END criterion=friedman_mse, learning_rate=0.1, max_depth=9, max_features=auto, min_samples_leaf=7, min_samples_split=2, n_estimators=50; total time=   1.0s
# [CV] END criterion=friedman_mse, learning_rate=0.1, max_depth=9, max_features=auto, min_samples_leaf=7, min_samples_split=2, n_estimators=50; total time=   1.0s
# [CV] END criterion=friedman_mse, learning_rate=0.1, max_depth=9, max_features=auto, min_samples_leaf=7, min_samples_split=2, n_estimators=50; total time=   1.0s
# [CV] END criterion=friedman_mse, learning_rate=0.1, max_depth=9, max_features=auto, min_samples_leaf=7, min_samples_split=6, n_estimators=50; total time=   1.0s
# [CV] END criterion=friedman_mse, learning_rate=0.1, max_depth=9, max_features=auto, min_samples_leaf=7, min_samples_split=6, n_estimators=50; total time=   1.0s
# [CV] END criterion=friedman_mse, learning_rate=0.1, max_depth=9, max_features=auto, min_samples_leaf=7, min_samples_split=6, n_estimators=50; total time=   1.0s
# [CV] END criterion=friedman_mse, learning_rate=0.1, max_depth=9, max_features=auto, min_samples_leaf=7, min_samples_split=6, n_estimators=50; total time=   1.0s
# [CV] END criterion=friedman_mse, learning_rate=0.1, max_depth=9, max_features=auto, min_samples_leaf=7, min_samples_split=6, n_estimators=50; total time=   1.0s
# [CV] END criterion=friedman_mse, learning_rate=0.1, max_depth=10, max_features=auto, min_samples_leaf=5, min_samples_split=5, n_estimators=50; total time=   1.1s
# [CV] END criterion=friedman_mse, learning_rate=0.1, max_depth=10, max_features=auto, min_samples_leaf=5, min_samples_split=5, n_estimators=50; total time=   1.1s
# [CV] END criterion=friedman_mse, learning_rate=0.1, max_depth=10, max_features=auto, min_samples_leaf=5, min_samples_split=5, n_estimators=50; total time=   1.1s
# [CV] END criterion=friedman_mse, learning_rate=0.1, max_depth=10, max_features=auto, min_samples_leaf=5, min_samples_split=5, n_estimators=50; total time=   1.1s
# [CV] END criterion=friedman_mse, learning_rate=0.1, max_depth=10, max_features=auto, min_samples_leaf=5, min_samples_split=5, n_estimators=50; total time=   1.1s
# [CV] END criterion=friedman_mse, learning_rate=0.1, max_depth=10, max_features=auto, min_samples_leaf=5, min_samples_split=2, n_estimators=50; total time=   1.1s
# [CV] END criterion=friedman_mse, learning_rate=0.1, max_depth=10, max_features=auto, min_samples_leaf=5, min_samples_split=2, n_estimators=50; total time=   1.1s
# [CV] END criterion=friedman_mse, learning_rate=0.1, max_depth=10, max_features=auto, min_samples_leaf=5, min_samples_split=2, n_estimators=50; total time=   1.1s
# [CV] END criterion=friedman_mse, learning_rate=0.1, max_depth=10, max_features=auto, min_samples_leaf=5, min_samples_split=2, n_estimators=50; total time=   1.1s
# [CV] END criterion=friedman_mse, learning_rate=0.1, max_depth=10, max_features=auto, min_samples_leaf=5, min_samples_split=2, n_estimators=50; total time=   1.1s
# [CV] END criterion=friedman_mse, learning_rate=0.1, max_depth=10, max_features=auto, min_samples_leaf=5, min_samples_split=6, n_estimators=50; total time=   1.1s
# [CV] END criterion=friedman_mse, learning_rate=0.1, max_depth=10, max_features=auto, min_samples_leaf=5, min_samples_split=6, n_estimators=50; total time=   1.1s
# [CV] END criterion=friedman_mse, learning_rate=0.1, max_depth=10, max_features=auto, min_samples_leaf=5, min_samples_split=6, n_estimators=50; total time=   1.1s
# [CV] END criterion=friedman_mse, learning_rate=0.1, max_depth=10, max_features=auto, min_samples_leaf=5, min_samples_split=6, n_estimators=50; total time=   1.1s
# [CV] END criterion=friedman_mse, learning_rate=0.1, max_depth=10, max_features=auto, min_samples_leaf=5, min_samples_split=6, n_estimators=50; total time=   1.1s
# [CV] END criterion=friedman_mse, learning_rate=0.1, max_depth=10, max_features=auto, min_samples_leaf=6, min_samples_split=5, n_estimators=50; total time=   1.1s
# [CV] END criterion=friedman_mse, learning_rate=0.1, max_depth=10, max_features=auto, min_samples_leaf=6, min_samples_split=5, n_estimators=50; total time=   1.1s
# [CV] END criterion=friedman_mse, learning_rate=0.1, max_depth=10, max_features=auto, min_samples_leaf=6, min_samples_split=5, n_estimators=50; total time=   1.1s
# [CV] END criterion=friedman_mse, learning_rate=0.1, max_depth=10, max_features=auto, min_samples_leaf=6, min_samples_split=5, n_estimators=50; total time=   1.1s
# [CV] END criterion=friedman_mse, learning_rate=0.1, max_depth=10, max_features=auto, min_samples_leaf=6, min_samples_split=5, n_estimators=50; total time=   1.1s
# [CV] END criterion=friedman_mse, learning_rate=0.1, max_depth=10, max_features=auto, min_samples_leaf=6, min_samples_split=2, n_estimators=50; total time=   1.1s
# [CV] END criterion=friedman_mse, learning_rate=0.1, max_depth=10, max_features=auto, min_samples_leaf=6, min_samples_split=2, n_estimators=50; total time=   1.1s
# [CV] END criterion=friedman_mse, learning_rate=0.1, max_depth=10, max_features=auto, min_samples_leaf=6, min_samples_split=2, n_estimators=50; total time=   1.1s
# [CV] END criterion=friedman_mse, learning_rate=0.1, max_depth=10, max_features=auto, min_samples_leaf=6, min_samples_split=2, n_estimators=50; total time=   1.1s
# [CV] END criterion=friedman_mse, learning_rate=0.1, max_depth=10, max_features=auto, min_samples_leaf=6, min_samples_split=2, n_estimators=50; total time=   1.1s
# [CV] END criterion=friedman_mse, learning_rate=0.1, max_depth=10, max_features=auto, min_samples_leaf=6, min_samples_split=6, n_estimators=50; total time=   1.1s
# [CV] END criterion=friedman_mse, learning_rate=0.1, max_depth=10, max_features=auto, min_samples_leaf=6, min_samples_split=6, n_estimators=50; total time=   1.1s
# [CV] END criterion=friedman_mse, learning_rate=0.1, max_depth=10, max_features=auto, min_samples_leaf=6, min_samples_split=6, n_estimators=50; total time=   1.1s
# [CV] END criterion=friedman_mse, learning_rate=0.1, max_depth=10, max_features=auto, min_samples_leaf=6, min_samples_split=6, n_estimators=50; total time=   1.1s
# [CV] END criterion=friedman_mse, learning_rate=0.1, max_depth=10, max_features=auto, min_samples_leaf=6, min_samples_split=6, n_estimators=50; total time=   1.1s
# [CV] END criterion=friedman_mse, learning_rate=0.1, max_depth=10, max_features=auto, min_samples_leaf=7, min_samples_split=5, n_estimators=50; total time=   1.1s
# [CV] END criterion=friedman_mse, learning_rate=0.1, max_depth=10, max_features=auto, min_samples_leaf=7, min_samples_split=5, n_estimators=50; total time=   1.1s
# [CV] END criterion=friedman_mse, learning_rate=0.1, max_depth=10, max_features=auto, min_samples_leaf=7, min_samples_split=5, n_estimators=50; total time=   1.1s
# [CV] END criterion=friedman_mse, learning_rate=0.1, max_depth=10, max_features=auto, min_samples_leaf=7, min_samples_split=5, n_estimators=50; total time=   1.1s
# [CV] END criterion=friedman_mse, learning_rate=0.1, max_depth=10, max_features=auto, min_samples_leaf=7, min_samples_split=5, n_estimators=50; total time=   1.1s
# [CV] END criterion=friedman_mse, learning_rate=0.1, max_depth=10, max_features=auto, min_samples_leaf=7, min_samples_split=2, n_estimators=50; total time=   1.1s
# [CV] END criterion=friedman_mse, learning_rate=0.1, max_depth=10, max_features=auto, min_samples_leaf=7, min_samples_split=2, n_estimators=50; total time=   1.1s
# [CV] END criterion=friedman_mse, learning_rate=0.1, max_depth=10, max_features=auto, min_samples_leaf=7, min_samples_split=2, n_estimators=50; total time=   1.1s
# [CV] END criterion=friedman_mse, learning_rate=0.1, max_depth=10, max_features=auto, min_samples_leaf=7, min_samples_split=2, n_estimators=50; total time=   1.1s
# [CV] END criterion=friedman_mse, learning_rate=0.1, max_depth=10, max_features=auto, min_samples_leaf=7, min_samples_split=2, n_estimators=50; total time=   1.1s
# [CV] END criterion=friedman_mse, learning_rate=0.1, max_depth=10, max_features=auto, min_samples_leaf=7, min_samples_split=6, n_estimators=50; total time=   1.1s
# [CV] END criterion=friedman_mse, learning_rate=0.1, max_depth=10, max_features=auto, min_samples_leaf=7, min_samples_split=6, n_estimators=50; total time=   1.1s
# [CV] END criterion=friedman_mse, learning_rate=0.1, max_depth=10, max_features=auto, min_samples_leaf=7, min_samples_split=6, n_estimators=50; total time=   1.1s
# [CV] END criterion=friedman_mse, learning_rate=0.1, max_depth=10, max_features=auto, min_samples_leaf=7, min_samples_split=6, n_estimators=50; total time=   1.1s
# [CV] END criterion=friedman_mse, learning_rate=0.1, max_depth=10, max_features=auto, min_samples_leaf=7, min_samples_split=6, n_estimators=50; total time=   1.1s
# GridSearchCV(cv=5, estimator=GradientBoostingRegressor(),
#              param_grid={'criterion': ['friedman_mse'],
#                          'learning_rate': [0.001, 0.1], 'max_depth': [8, 9, 10],
#                          'max_features': ['auto'],
#                          'min_samples_leaf': [5, 6, 7],
#                          'min_samples_split': [5, 2, 6], 'n_estimators': [50]},
#              scoring='roc_auc', verbose=2)

# %%
# BEST HYPER PARAMETER
rf_grid.best_params_
# Out:
# {'criterion': 'friedman_mse',
#  'learning_rate': 0.001,
#  'max_depth': 8,
#  'max_features': 'auto',
#  'min_samples_leaf': 5,
#  'min_samples_split': 5,
#  'n_estimators': 50}

# %%
# USING BEST HYPER PARAMENTER OM THE MODEL
gbr = GradientBoostingRegressor(criterion = 'friedman_mse',
  learning_rate = 0.1,
  max_depth = 25,
  max_features = 'auto',
  min_samples_leaf = 20,
  min_samples_split = 10,
  n_estimators = 50)

# %%
#  MODEL FITIING ON TRAIN DATASET
gbr.fit(X_train, Y_train)
# Out:
# GradientBoostingRegressor(max_depth=25, max_features='auto',
#                           min_samples_leaf=20, min_samples_split=10,
#                           n_estimators=50)

# %%
# PREDICTING X_TEST
y_pred = gbr.predict(X_test)

# %%
# R_SQUARED
r2_score(Y_test, y_pred)
# Out:
# 0.8915422581415864

# %%
#  MODEL FITIING ON TRAIN DATASET
gbr.score(X_train, Y_train)
# Out:
# 0.9680545053226108

# %%
#  MODEL FITIING ON TEST DATASET
gbr.score(X_test, Y_test)
# Out:
# 0.8915422581415864

# %%
# ADJUSTED R-SQURED , MEAN SQUARED ERROR, ROOT MEAN SQUARED ERROR
print("Adjusted R2 : ",1-(1-r2_score((Y_test), (y_pred)))*((X_test.shape[0]-1)/(X_test.shape[0]-X_test.shape[1]-1)))
MSE  = mean_squared_error(Y_test, y_pred)
print("MSE :" , MSE)
RMSE = np.sqrt(MSE)
print("RMSE :" ,RMSE)
# Out:
# Adjusted R2 :  0.8907436737560666
# MSE : 44380.24482552315
# RMSE : 210.66619288704857

# %%
# PLOTTING FIRST 50 Y_TEST AND Y_PRED
plt.figure(figsize=(15,10))
plt.plot(np.array(Y_test[:50]), color = "orange")
plt.plot(y_pred[:50], color = "red")
plt.title("GradientBoostingRegressor")
plt.legend(["Predicted","Actual"])
plt.show()

# %% [markdown]
# XGB

# %%
# IMPORTING XGBRegressor
from xgboost import XGBRegressor

# %%
# PERFORMING HYPERPARAMETER TUNNING AND FITTING THE TRAIN DATASET 
rf_grid = GridSearchCV(XGBRegressor(),
                       param_grid = {"min_child_weight":[10,20], 
            'eta': [0.004,0.1, 0.11, 0.01], 
            'colsample_bytree':[0.7, 0.1], 
            'max_depth': [15,17, 20],
          
          }, cv=5 , verbose=2)
rf_grid.fit(X_train,Y_train)
# Out:
# Fitting 5 folds for each of 48 candidates, totalling 240 fits
# [14:34:02] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END colsample_bytree=0.7, eta=0.004, max_depth=15, min_child_weight=10; total time=   1.5s
# [14:34:03] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END colsample_bytree=0.7, eta=0.004, max_depth=15, min_child_weight=10; total time=   1.5s
# [14:34:05] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END colsample_bytree=0.7, eta=0.004, max_depth=15, min_child_weight=10; total time=   1.5s
# [14:34:06] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END colsample_bytree=0.7, eta=0.004, max_depth=15, min_child_weight=10; total time=   1.5s
# [14:34:08] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END colsample_bytree=0.7, eta=0.004, max_depth=15, min_child_weight=10; total time=   1.5s
# [14:34:09] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END colsample_bytree=0.7, eta=0.004, max_depth=15, min_child_weight=20; total time=   1.3s
# [14:34:11] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END colsample_bytree=0.7, eta=0.004, max_depth=15, min_child_weight=20; total time=   1.3s
# [14:34:12] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END colsample_bytree=0.7, eta=0.004, max_depth=15, min_child_weight=20; total time=   1.3s
# [14:34:13] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END colsample_bytree=0.7, eta=0.004, max_depth=15, min_child_weight=20; total time=   1.4s
# [14:34:15] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END colsample_bytree=0.7, eta=0.004, max_depth=15, min_child_weight=20; total time=   1.3s
# [14:34:16] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END colsample_bytree=0.7, eta=0.004, max_depth=17, min_child_weight=10; total time=   1.6s
# [14:34:18] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END colsample_bytree=0.7, eta=0.004, max_depth=17, min_child_weight=10; total time=   1.6s
# [14:34:19] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END colsample_bytree=0.7, eta=0.004, max_depth=17, min_child_weight=10; total time=   1.6s
# [14:34:21] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END colsample_bytree=0.7, eta=0.004, max_depth=17, min_child_weight=10; total time=   1.6s
# [14:34:22] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END colsample_bytree=0.7, eta=0.004, max_depth=17, min_child_weight=10; total time=   1.6s
# [14:34:24] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END colsample_bytree=0.7, eta=0.004, max_depth=17, min_child_weight=20; total time=   1.5s
# [14:34:26] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END colsample_bytree=0.7, eta=0.004, max_depth=17, min_child_weight=20; total time=   1.4s
# [14:34:27] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END colsample_bytree=0.7, eta=0.004, max_depth=17, min_child_weight=20; total time=   1.4s
# [14:34:28] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END colsample_bytree=0.7, eta=0.004, max_depth=17, min_child_weight=20; total time=   1.5s
# [14:34:30] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END colsample_bytree=0.7, eta=0.004, max_depth=17, min_child_weight=20; total time=   1.4s
# [14:34:31] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END colsample_bytree=0.7, eta=0.004, max_depth=20, min_child_weight=10; total time=   1.8s
# [14:34:33] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END colsample_bytree=0.7, eta=0.004, max_depth=20, min_child_weight=10; total time=   1.8s
# [14:34:35] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END colsample_bytree=0.7, eta=0.004, max_depth=20, min_child_weight=10; total time=   1.8s
# [14:34:37] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END colsample_bytree=0.7, eta=0.004, max_depth=20, min_child_weight=10; total time=   1.8s
# [14:34:38] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END colsample_bytree=0.7, eta=0.004, max_depth=20, min_child_weight=10; total time=   1.8s
# [14:34:40] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END colsample_bytree=0.7, eta=0.004, max_depth=20, min_child_weight=20; total time=   1.6s
# [14:34:42] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END colsample_bytree=0.7, eta=0.004, max_depth=20, min_child_weight=20; total time=   1.6s
# [14:34:43] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END colsample_bytree=0.7, eta=0.004, max_depth=20, min_child_weight=20; total time=   1.6s
# [14:34:45] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END colsample_bytree=0.7, eta=0.004, max_depth=20, min_child_weight=20; total time=   1.6s
# [14:34:47] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END colsample_bytree=0.7, eta=0.004, max_depth=20, min_child_weight=20; total time=   1.6s
# [14:34:48] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END colsample_bytree=0.7, eta=0.1, max_depth=15, min_child_weight=10; total time=   1.4s
# [14:34:50] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END colsample_bytree=0.7, eta=0.1, max_depth=15, min_child_weight=10; total time=   1.4s
# [14:34:51] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END colsample_bytree=0.7, eta=0.1, max_depth=15, min_child_weight=10; total time=   1.4s
# [14:34:52] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END colsample_bytree=0.7, eta=0.1, max_depth=15, min_child_weight=10; total time=   1.5s
# [14:34:54] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END colsample_bytree=0.7, eta=0.1, max_depth=15, min_child_weight=10; total time=   1.5s
# [14:34:55] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END colsample_bytree=0.7, eta=0.1, max_depth=15, min_child_weight=20; total time=   1.3s
# [14:34:57] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END colsample_bytree=0.7, eta=0.1, max_depth=15, min_child_weight=20; total time=   1.3s
# [14:34:58] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END colsample_bytree=0.7, eta=0.1, max_depth=15, min_child_weight=20; total time=   1.3s
# [14:34:59] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END colsample_bytree=0.7, eta=0.1, max_depth=15, min_child_weight=20; total time=   1.4s
# [14:35:01] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END colsample_bytree=0.7, eta=0.1, max_depth=15, min_child_weight=20; total time=   1.3s
# [14:35:02] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END colsample_bytree=0.7, eta=0.1, max_depth=17, min_child_weight=10; total time=   1.6s
# [14:35:04] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END colsample_bytree=0.7, eta=0.1, max_depth=17, min_child_weight=10; total time=   1.6s
# [14:35:05] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END colsample_bytree=0.7, eta=0.1, max_depth=17, min_child_weight=10; total time=   1.6s
# [14:35:07] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END colsample_bytree=0.7, eta=0.1, max_depth=17, min_child_weight=10; total time=   1.6s
# [14:35:08] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END colsample_bytree=0.7, eta=0.1, max_depth=17, min_child_weight=10; total time=   1.6s
# [14:35:10] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END colsample_bytree=0.7, eta=0.1, max_depth=17, min_child_weight=20; total time=   1.5s
# [14:35:12] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END colsample_bytree=0.7, eta=0.1, max_depth=17, min_child_weight=20; total time=   1.4s
# [14:35:13] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END colsample_bytree=0.7, eta=0.1, max_depth=17, min_child_weight=20; total time=   1.4s
# [14:35:14] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END colsample_bytree=0.7, eta=0.1, max_depth=17, min_child_weight=20; total time=   1.5s
# [14:35:16] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END colsample_bytree=0.7, eta=0.1, max_depth=17, min_child_weight=20; total time=   1.5s
# [14:35:17] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END colsample_bytree=0.7, eta=0.1, max_depth=20, min_child_weight=10; total time=   1.8s
# [14:35:19] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END colsample_bytree=0.7, eta=0.1, max_depth=20, min_child_weight=10; total time=   1.8s
# [14:35:21] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END colsample_bytree=0.7, eta=0.1, max_depth=20, min_child_weight=10; total time=   1.8s
# [14:35:23] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END colsample_bytree=0.7, eta=0.1, max_depth=20, min_child_weight=10; total time=   1.8s
# [14:35:24] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END colsample_bytree=0.7, eta=0.1, max_depth=20, min_child_weight=10; total time=   1.8s
# [14:35:26] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END colsample_bytree=0.7, eta=0.1, max_depth=20, min_child_weight=20; total time=   1.6s
# [14:35:28] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END colsample_bytree=0.7, eta=0.1, max_depth=20, min_child_weight=20; total time=   1.6s
# [14:35:29] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END colsample_bytree=0.7, eta=0.1, max_depth=20, min_child_weight=20; total time=   1.6s
# [14:35:31] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END colsample_bytree=0.7, eta=0.1, max_depth=20, min_child_weight=20; total time=   1.6s
# [14:35:33] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END colsample_bytree=0.7, eta=0.1, max_depth=20, min_child_weight=20; total time=   1.6s
# [14:35:34] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END colsample_bytree=0.7, eta=0.11, max_depth=15, min_child_weight=10; total time=   1.5s
# [14:35:36] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END colsample_bytree=0.7, eta=0.11, max_depth=15, min_child_weight=10; total time=   1.4s
# [14:35:37] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END colsample_bytree=0.7, eta=0.11, max_depth=15, min_child_weight=10; total time=   1.5s
# [14:35:39] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END colsample_bytree=0.7, eta=0.11, max_depth=15, min_child_weight=10; total time=   1.5s
# [14:35:40] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END colsample_bytree=0.7, eta=0.11, max_depth=15, min_child_weight=10; total time=   1.5s
# [14:35:41] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END colsample_bytree=0.7, eta=0.11, max_depth=15, min_child_weight=20; total time=   1.3s
# [14:35:43] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END colsample_bytree=0.7, eta=0.11, max_depth=15, min_child_weight=20; total time=   1.3s
# [14:35:44] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END colsample_bytree=0.7, eta=0.11, max_depth=15, min_child_weight=20; total time=   1.3s
# [14:35:45] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END colsample_bytree=0.7, eta=0.11, max_depth=15, min_child_weight=20; total time=   1.4s
# [14:35:47] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END colsample_bytree=0.7, eta=0.11, max_depth=15, min_child_weight=20; total time=   1.3s
# [14:35:48] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END colsample_bytree=0.7, eta=0.11, max_depth=17, min_child_weight=10; total time=   1.6s
# [14:35:50] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END colsample_bytree=0.7, eta=0.11, max_depth=17, min_child_weight=10; total time=   1.6s
# [14:35:51] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END colsample_bytree=0.7, eta=0.11, max_depth=17, min_child_weight=10; total time=   1.6s
# [14:35:53] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END colsample_bytree=0.7, eta=0.11, max_depth=17, min_child_weight=10; total time=   1.6s
# [14:35:55] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END colsample_bytree=0.7, eta=0.11, max_depth=17, min_child_weight=10; total time=   1.6s
# [14:35:56] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END colsample_bytree=0.7, eta=0.11, max_depth=17, min_child_weight=20; total time=   1.5s
# [14:35:58] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END colsample_bytree=0.7, eta=0.11, max_depth=17, min_child_weight=20; total time=   1.5s
# [14:35:59] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END colsample_bytree=0.7, eta=0.11, max_depth=17, min_child_weight=20; total time=   1.4s
# [14:36:01] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END colsample_bytree=0.7, eta=0.11, max_depth=17, min_child_weight=20; total time=   1.5s
# [14:36:02] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END colsample_bytree=0.7, eta=0.11, max_depth=17, min_child_weight=20; total time=   1.4s
# [14:36:03] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END colsample_bytree=0.7, eta=0.11, max_depth=20, min_child_weight=10; total time=   1.8s
# [14:36:05] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END colsample_bytree=0.7, eta=0.11, max_depth=20, min_child_weight=10; total time=   1.8s
# [14:36:07] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END colsample_bytree=0.7, eta=0.11, max_depth=20, min_child_weight=10; total time=   1.8s
# [14:36:09] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END colsample_bytree=0.7, eta=0.11, max_depth=20, min_child_weight=10; total time=   1.8s
# [14:36:11] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END colsample_bytree=0.7, eta=0.11, max_depth=20, min_child_weight=10; total time=   1.8s
# [14:36:12] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END colsample_bytree=0.7, eta=0.11, max_depth=20, min_child_weight=20; total time=   1.6s
# [14:36:14] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END colsample_bytree=0.7, eta=0.11, max_depth=20, min_child_weight=20; total time=   1.6s
# [14:36:16] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END colsample_bytree=0.7, eta=0.11, max_depth=20, min_child_weight=20; total time=   1.6s
# [14:36:17] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END colsample_bytree=0.7, eta=0.11, max_depth=20, min_child_weight=20; total time=   1.6s
# [14:36:19] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END colsample_bytree=0.7, eta=0.11, max_depth=20, min_child_weight=20; total time=   1.6s
# [14:36:20] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END colsample_bytree=0.7, eta=0.01, max_depth=15, min_child_weight=10; total time=   1.4s
# [14:36:22] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END colsample_bytree=0.7, eta=0.01, max_depth=15, min_child_weight=10; total time=   1.4s
# [14:36:23] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END colsample_bytree=0.7, eta=0.01, max_depth=15, min_child_weight=10; total time=   1.4s
# [14:36:25] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END colsample_bytree=0.7, eta=0.01, max_depth=15, min_child_weight=10; total time=   1.5s
# [14:36:26] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END colsample_bytree=0.7, eta=0.01, max_depth=15, min_child_weight=10; total time=   1.5s
# [14:36:28] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END colsample_bytree=0.7, eta=0.01, max_depth=15, min_child_weight=20; total time=   1.3s
# [14:36:29] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END colsample_bytree=0.7, eta=0.01, max_depth=15, min_child_weight=20; total time=   1.3s
# [14:36:30] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END colsample_bytree=0.7, eta=0.01, max_depth=15, min_child_weight=20; total time=   1.3s
# [14:36:32] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END colsample_bytree=0.7, eta=0.01, max_depth=15, min_child_weight=20; total time=   1.4s
# [14:36:33] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END colsample_bytree=0.7, eta=0.01, max_depth=15, min_child_weight=20; total time=   1.3s
# [14:36:34] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END colsample_bytree=0.7, eta=0.01, max_depth=17, min_child_weight=10; total time=   1.6s
# [14:36:36] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END colsample_bytree=0.7, eta=0.01, max_depth=17, min_child_weight=10; total time=   1.6s
# [14:36:38] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END colsample_bytree=0.7, eta=0.01, max_depth=17, min_child_weight=10; total time=   1.6s
# [14:36:39] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END colsample_bytree=0.7, eta=0.01, max_depth=17, min_child_weight=10; total time=   1.6s
# [14:36:41] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END colsample_bytree=0.7, eta=0.01, max_depth=17, min_child_weight=10; total time=   1.6s
# [14:36:42] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END colsample_bytree=0.7, eta=0.01, max_depth=17, min_child_weight=20; total time=   1.5s
# [14:36:44] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END colsample_bytree=0.7, eta=0.01, max_depth=17, min_child_weight=20; total time=   1.5s
# [14:36:45] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END colsample_bytree=0.7, eta=0.01, max_depth=17, min_child_weight=20; total time=   1.4s
# [14:36:47] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END colsample_bytree=0.7, eta=0.01, max_depth=17, min_child_weight=20; total time=   1.4s
# [14:36:48] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END colsample_bytree=0.7, eta=0.01, max_depth=17, min_child_weight=20; total time=   1.4s
# [14:36:50] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END colsample_bytree=0.7, eta=0.01, max_depth=20, min_child_weight=10; total time=   1.8s
# [14:36:51] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END colsample_bytree=0.7, eta=0.01, max_depth=20, min_child_weight=10; total time=   1.8s
# [14:36:53] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END colsample_bytree=0.7, eta=0.01, max_depth=20, min_child_weight=10; total time=   1.8s
# [14:36:55] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END colsample_bytree=0.7, eta=0.01, max_depth=20, min_child_weight=10; total time=   1.8s
# [14:36:57] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END colsample_bytree=0.7, eta=0.01, max_depth=20, min_child_weight=10; total time=   1.8s
# [14:36:59] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END colsample_bytree=0.7, eta=0.01, max_depth=20, min_child_weight=20; total time=   1.6s
# [14:37:00] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END colsample_bytree=0.7, eta=0.01, max_depth=20, min_child_weight=20; total time=   1.6s
# [14:37:02] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END colsample_bytree=0.7, eta=0.01, max_depth=20, min_child_weight=20; total time=   1.6s
# [14:37:03] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END colsample_bytree=0.7, eta=0.01, max_depth=20, min_child_weight=20; total time=   1.6s
# [14:37:05] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END colsample_bytree=0.7, eta=0.01, max_depth=20, min_child_weight=20; total time=   1.6s
# [14:37:06] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END colsample_bytree=0.1, eta=0.004, max_depth=15, min_child_weight=10; total time=   0.3s
# [14:37:07] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END colsample_bytree=0.1, eta=0.004, max_depth=15, min_child_weight=10; total time=   0.3s
# [14:37:07] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END colsample_bytree=0.1, eta=0.004, max_depth=15, min_child_weight=10; total time=   0.3s
# [14:37:07] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END colsample_bytree=0.1, eta=0.004, max_depth=15, min_child_weight=10; total time=   0.3s
# [14:37:08] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END colsample_bytree=0.1, eta=0.004, max_depth=15, min_child_weight=10; total time=   0.3s
# [14:37:08] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END colsample_bytree=0.1, eta=0.004, max_depth=15, min_child_weight=20; total time=   0.2s
# [14:37:08] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END colsample_bytree=0.1, eta=0.004, max_depth=15, min_child_weight=20; total time=   0.3s
# [14:37:08] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END colsample_bytree=0.1, eta=0.004, max_depth=15, min_child_weight=20; total time=   0.2s
# [14:37:09] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END colsample_bytree=0.1, eta=0.004, max_depth=15, min_child_weight=20; total time=   0.3s
# [14:37:09] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END colsample_bytree=0.1, eta=0.004, max_depth=15, min_child_weight=20; total time=   0.3s
# [14:37:09] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END colsample_bytree=0.1, eta=0.004, max_depth=17, min_child_weight=10; total time=   0.3s
# [14:37:09] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END colsample_bytree=0.1, eta=0.004, max_depth=17, min_child_weight=10; total time=   0.3s
# [14:37:10] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END colsample_bytree=0.1, eta=0.004, max_depth=17, min_child_weight=10; total time=   0.3s
# [14:37:10] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END colsample_bytree=0.1, eta=0.004, max_depth=17, min_child_weight=10; total time=   0.3s
# [14:37:10] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END colsample_bytree=0.1, eta=0.004, max_depth=17, min_child_weight=10; total time=   0.3s
# [14:37:10] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END colsample_bytree=0.1, eta=0.004, max_depth=17, min_child_weight=20; total time=   0.3s
# [14:37:11] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END colsample_bytree=0.1, eta=0.004, max_depth=17, min_child_weight=20; total time=   0.2s
# [14:37:11] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END colsample_bytree=0.1, eta=0.004, max_depth=17, min_child_weight=20; total time=   0.2s
# [14:37:11] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END colsample_bytree=0.1, eta=0.004, max_depth=17, min_child_weight=20; total time=   0.3s
# [14:37:11] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END colsample_bytree=0.1, eta=0.004, max_depth=17, min_child_weight=20; total time=   0.3s
# [14:37:12] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END colsample_bytree=0.1, eta=0.004, max_depth=20, min_child_weight=10; total time=   0.3s
# [14:37:12] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END colsample_bytree=0.1, eta=0.004, max_depth=20, min_child_weight=10; total time=   0.3s
# [14:37:12] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END colsample_bytree=0.1, eta=0.004, max_depth=20, min_child_weight=10; total time=   0.3s
# [14:37:12] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END colsample_bytree=0.1, eta=0.004, max_depth=20, min_child_weight=10; total time=   0.3s
# [14:37:13] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END colsample_bytree=0.1, eta=0.004, max_depth=20, min_child_weight=10; total time=   0.3s
# [14:37:13] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END colsample_bytree=0.1, eta=0.004, max_depth=20, min_child_weight=20; total time=   0.3s
# [14:37:13] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END colsample_bytree=0.1, eta=0.004, max_depth=20, min_child_weight=20; total time=   0.3s
# [14:37:14] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END colsample_bytree=0.1, eta=0.004, max_depth=20, min_child_weight=20; total time=   0.3s
# [14:37:14] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END colsample_bytree=0.1, eta=0.004, max_depth=20, min_child_weight=20; total time=   0.3s
# [14:37:14] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END colsample_bytree=0.1, eta=0.004, max_depth=20, min_child_weight=20; total time=   0.3s
# [14:37:14] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END colsample_bytree=0.1, eta=0.1, max_depth=15, min_child_weight=10; total time=   0.3s
# [14:37:15] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END colsample_bytree=0.1, eta=0.1, max_depth=15, min_child_weight=10; total time=   0.3s
# [14:37:15] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END colsample_bytree=0.1, eta=0.1, max_depth=15, min_child_weight=10; total time=   0.3s
# [14:37:15] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END colsample_bytree=0.1, eta=0.1, max_depth=15, min_child_weight=10; total time=   0.3s
# [14:37:15] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END colsample_bytree=0.1, eta=0.1, max_depth=15, min_child_weight=10; total time=   0.3s
# [14:37:16] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END colsample_bytree=0.1, eta=0.1, max_depth=15, min_child_weight=20; total time=   0.2s
# [14:37:16] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END colsample_bytree=0.1, eta=0.1, max_depth=15, min_child_weight=20; total time=   0.2s
# [14:37:16] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END colsample_bytree=0.1, eta=0.1, max_depth=15, min_child_weight=20; total time=   0.3s
# [14:37:16] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END colsample_bytree=0.1, eta=0.1, max_depth=15, min_child_weight=20; total time=   0.3s
# [14:37:17] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END colsample_bytree=0.1, eta=0.1, max_depth=15, min_child_weight=20; total time=   0.2s
# [14:37:17] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END colsample_bytree=0.1, eta=0.1, max_depth=17, min_child_weight=10; total time=   0.3s
# [14:37:17] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END colsample_bytree=0.1, eta=0.1, max_depth=17, min_child_weight=10; total time=   0.3s
# [14:37:17] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END colsample_bytree=0.1, eta=0.1, max_depth=17, min_child_weight=10; total time=   0.3s
# [14:37:18] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END colsample_bytree=0.1, eta=0.1, max_depth=17, min_child_weight=10; total time=   0.3s
# [14:37:18] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END colsample_bytree=0.1, eta=0.1, max_depth=17, min_child_weight=10; total time=   0.3s
# [14:37:18] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END colsample_bytree=0.1, eta=0.1, max_depth=17, min_child_weight=20; total time=   0.3s
# [14:37:18] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END colsample_bytree=0.1, eta=0.1, max_depth=17, min_child_weight=20; total time=   0.2s
# [14:37:19] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END colsample_bytree=0.1, eta=0.1, max_depth=17, min_child_weight=20; total time=   0.3s
# [14:37:19] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END colsample_bytree=0.1, eta=0.1, max_depth=17, min_child_weight=20; total time=   0.3s
# [14:37:19] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END colsample_bytree=0.1, eta=0.1, max_depth=17, min_child_weight=20; total time=   0.3s
# [14:37:19] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END colsample_bytree=0.1, eta=0.1, max_depth=20, min_child_weight=10; total time=   0.3s
# [14:37:20] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END colsample_bytree=0.1, eta=0.1, max_depth=20, min_child_weight=10; total time=   0.3s
# [14:37:20] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END colsample_bytree=0.1, eta=0.1, max_depth=20, min_child_weight=10; total time=   0.3s
# [14:37:20] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END colsample_bytree=0.1, eta=0.1, max_depth=20, min_child_weight=10; total time=   0.3s
# [14:37:21] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END colsample_bytree=0.1, eta=0.1, max_depth=20, min_child_weight=10; total time=   0.3s
# [14:37:21] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END colsample_bytree=0.1, eta=0.1, max_depth=20, min_child_weight=20; total time=   0.3s
# [14:37:21] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END colsample_bytree=0.1, eta=0.1, max_depth=20, min_child_weight=20; total time=   0.3s
# [14:37:21] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END colsample_bytree=0.1, eta=0.1, max_depth=20, min_child_weight=20; total time=   0.3s
# [14:37:22] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END colsample_bytree=0.1, eta=0.1, max_depth=20, min_child_weight=20; total time=   0.3s
# [14:37:22] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END colsample_bytree=0.1, eta=0.1, max_depth=20, min_child_weight=20; total time=   0.3s
# [14:37:22] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END colsample_bytree=0.1, eta=0.11, max_depth=15, min_child_weight=10; total time=   0.3s
# [14:37:22] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END colsample_bytree=0.1, eta=0.11, max_depth=15, min_child_weight=10; total time=   0.3s
# [14:37:23] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END colsample_bytree=0.1, eta=0.11, max_depth=15, min_child_weight=10; total time=   0.3s
# [14:37:23] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END colsample_bytree=0.1, eta=0.11, max_depth=15, min_child_weight=10; total time=   0.3s
# [14:37:23] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END colsample_bytree=0.1, eta=0.11, max_depth=15, min_child_weight=10; total time=   0.3s
# [14:37:23] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END colsample_bytree=0.1, eta=0.11, max_depth=15, min_child_weight=20; total time=   0.2s
# [14:37:24] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END colsample_bytree=0.1, eta=0.11, max_depth=15, min_child_weight=20; total time=   0.2s
# [14:37:24] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END colsample_bytree=0.1, eta=0.11, max_depth=15, min_child_weight=20; total time=   0.2s
# [14:37:24] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END colsample_bytree=0.1, eta=0.11, max_depth=15, min_child_weight=20; total time=   0.3s
# [14:37:24] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END colsample_bytree=0.1, eta=0.11, max_depth=15, min_child_weight=20; total time=   0.3s
# [14:37:25] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END colsample_bytree=0.1, eta=0.11, max_depth=17, min_child_weight=10; total time=   0.3s
# [14:37:25] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END colsample_bytree=0.1, eta=0.11, max_depth=17, min_child_weight=10; total time=   0.3s
# [14:37:25] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END colsample_bytree=0.1, eta=0.11, max_depth=17, min_child_weight=10; total time=   0.3s
# [14:37:26] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END colsample_bytree=0.1, eta=0.11, max_depth=17, min_child_weight=10; total time=   0.3s
# [14:37:26] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END colsample_bytree=0.1, eta=0.11, max_depth=17, min_child_weight=10; total time=   0.3s
# [14:37:26] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END colsample_bytree=0.1, eta=0.11, max_depth=17, min_child_weight=20; total time=   0.3s
# [14:37:26] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END colsample_bytree=0.1, eta=0.11, max_depth=17, min_child_weight=20; total time=   0.3s
# [14:37:27] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END colsample_bytree=0.1, eta=0.11, max_depth=17, min_child_weight=20; total time=   0.3s
# [14:37:27] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END colsample_bytree=0.1, eta=0.11, max_depth=17, min_child_weight=20; total time=   0.3s
# [14:37:27] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END colsample_bytree=0.1, eta=0.11, max_depth=17, min_child_weight=20; total time=   0.3s
# [14:37:27] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END colsample_bytree=0.1, eta=0.11, max_depth=20, min_child_weight=10; total time=   0.3s
# [14:37:28] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END colsample_bytree=0.1, eta=0.11, max_depth=20, min_child_weight=10; total time=   0.3s
# [14:37:28] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END colsample_bytree=0.1, eta=0.11, max_depth=20, min_child_weight=10; total time=   0.3s
# [14:37:28] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END colsample_bytree=0.1, eta=0.11, max_depth=20, min_child_weight=10; total time=   0.3s
# [14:37:28] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END colsample_bytree=0.1, eta=0.11, max_depth=20, min_child_weight=10; total time=   0.3s
# [14:37:29] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END colsample_bytree=0.1, eta=0.11, max_depth=20, min_child_weight=20; total time=   0.3s
# [14:37:29] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END colsample_bytree=0.1, eta=0.11, max_depth=20, min_child_weight=20; total time=   0.2s
# [14:37:29] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END colsample_bytree=0.1, eta=0.11, max_depth=20, min_child_weight=20; total time=   0.3s
# [14:37:29] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END colsample_bytree=0.1, eta=0.11, max_depth=20, min_child_weight=20; total time=   0.3s
# [14:37:30] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END colsample_bytree=0.1, eta=0.11, max_depth=20, min_child_weight=20; total time=   0.3s
# [14:37:30] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END colsample_bytree=0.1, eta=0.01, max_depth=15, min_child_weight=10; total time=   0.3s
# [14:37:30] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END colsample_bytree=0.1, eta=0.01, max_depth=15, min_child_weight=10; total time=   0.3s
# [14:37:30] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END colsample_bytree=0.1, eta=0.01, max_depth=15, min_child_weight=10; total time=   0.3s
# [14:37:31] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END colsample_bytree=0.1, eta=0.01, max_depth=15, min_child_weight=10; total time=   0.3s
# [14:37:31] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END colsample_bytree=0.1, eta=0.01, max_depth=15, min_child_weight=10; total time=   0.3s
# [14:37:31] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END colsample_bytree=0.1, eta=0.01, max_depth=15, min_child_weight=20; total time=   0.2s
# [14:37:32] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END colsample_bytree=0.1, eta=0.01, max_depth=15, min_child_weight=20; total time=   0.3s
# [14:37:32] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END colsample_bytree=0.1, eta=0.01, max_depth=15, min_child_weight=20; total time=   0.2s
# [14:37:32] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END colsample_bytree=0.1, eta=0.01, max_depth=15, min_child_weight=20; total time=   0.2s
# [14:37:32] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END colsample_bytree=0.1, eta=0.01, max_depth=15, min_child_weight=20; total time=   0.3s
# [14:37:33] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END colsample_bytree=0.1, eta=0.01, max_depth=17, min_child_weight=10; total time=   0.3s
# [14:37:33] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END colsample_bytree=0.1, eta=0.01, max_depth=17, min_child_weight=10; total time=   0.3s
# [14:37:33] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END colsample_bytree=0.1, eta=0.01, max_depth=17, min_child_weight=10; total time=   0.3s
# [14:37:33] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END colsample_bytree=0.1, eta=0.01, max_depth=17, min_child_weight=10; total time=   0.3s
# [14:37:34] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END colsample_bytree=0.1, eta=0.01, max_depth=17, min_child_weight=10; total time=   0.3s
# [14:37:34] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END colsample_bytree=0.1, eta=0.01, max_depth=17, min_child_weight=20; total time=   0.3s
# [14:37:34] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END colsample_bytree=0.1, eta=0.01, max_depth=17, min_child_weight=20; total time=   0.2s
# [14:37:34] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END colsample_bytree=0.1, eta=0.01, max_depth=17, min_child_weight=20; total time=   0.3s
# [14:37:35] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END colsample_bytree=0.1, eta=0.01, max_depth=17, min_child_weight=20; total time=   0.3s
# [14:37:35] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END colsample_bytree=0.1, eta=0.01, max_depth=17, min_child_weight=20; total time=   0.2s
# [14:37:35] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END colsample_bytree=0.1, eta=0.01, max_depth=20, min_child_weight=10; total time=   0.3s
# [14:37:35] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END colsample_bytree=0.1, eta=0.01, max_depth=20, min_child_weight=10; total time=   0.3s
# [14:37:36] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END colsample_bytree=0.1, eta=0.01, max_depth=20, min_child_weight=10; total time=   0.3s
# [14:37:36] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END colsample_bytree=0.1, eta=0.01, max_depth=20, min_child_weight=10; total time=   0.3s
# [14:37:36] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END colsample_bytree=0.1, eta=0.01, max_depth=20, min_child_weight=10; total time=   0.3s
# [14:37:36] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END colsample_bytree=0.1, eta=0.01, max_depth=20, min_child_weight=20; total time=   0.3s
# [14:37:37] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END colsample_bytree=0.1, eta=0.01, max_depth=20, min_child_weight=20; total time=   0.3s
# [14:37:37] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END colsample_bytree=0.1, eta=0.01, max_depth=20, min_child_weight=20; total time=   0.2s
# [14:37:37] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END colsample_bytree=0.1, eta=0.01, max_depth=20, min_child_weight=20; total time=   0.3s
# [14:37:38] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END colsample_bytree=0.1, eta=0.01, max_depth=20, min_child_weight=20; total time=   0.3s
# [14:37:38] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# GridSearchCV(cv=5, estimator=XGBRegressor(),
#              param_grid={'colsample_bytree': [0.7, 0.1],
#                          'eta': [0.004, 0.1, 0.11, 0.01],
#                          'max_depth': [15, 17, 20],
#                          'min_child_weight': [10, 20]},
#              verbose=2)

# %%
# BEST HYPER PARAMETER
rf_grid.best_params_
# Out:
# {'colsample_bytree': 0.7,
#  'eta': 0.004,
#  'max_depth': 20,
#  'min_child_weight': 20}

# %%
# USING BEST HYPER PARAMENTER OM THE MODEL
xbr = XGBRegressor(
    colsample_bytree = 0.7,
    eta = 0.004,
    n_estimators = 100,
    gamma = 2,
 learning_rate = 0.1,
  max_depth = 25,
  min_child_weight = 15)

# %%
#  MODEL FITIING ON TRAIN DATASET
xbr.fit(X_train, Y_train)
# Out:
# [14:40:40] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# XGBRegressor(colsample_bytree=0.7, eta=0.004, gamma=2, max_depth=25,
#              min_child_weight=15)

# %%
# PREDICTING X_TEST
y_pred = xbr.predict(X_test)

# %%
# R_SQUARED
r2_score(Y_test, y_pred)
# Out:
# 0.8910984037576581

# %%
#  MODEL FITIING ON TRAIN DATASET
xbr.score(X_train, Y_train)
# Out:
# 0.990988031123465

# %%
#  MODEL FITIING ON TEST DATASET
xbr.score(X_test, Y_test)
# Out:
# 0.8910984037576581

# %%
# ADJUSTED R-SQURED , MEAN SQUARED ERROR, ROOT MEAN SQUARED ERROR
print("Adjusted R2 : ",1-(1-r2_score((Y_test), (y_pred)))*((X_test.shape[0]-1)/(X_test.shape[0]-X_test.shape[1]-1)))
MSE  = mean_squared_error(Y_test, y_pred)
print("MSE :" , MSE)
RMSE = np.sqrt(MSE)
print("RMSE :" ,RMSE)
# Out:
# Adjusted R2 :  0.8902965512312534
# MSE : 44561.86732556866
# RMSE : 211.09681979027695

# %%
# PLOTTING FIRST 50 Y_TEST AND Y_PRED
plt.figure(figsize=(15,10))
plt.plot(np.array(Y_test[:52]), color = "orange")
plt.plot(y_pred[:52], color = "red")
plt.title("XGBRegressor")
plt.legend(["Predicted","Actual"])
plt.show()

# %% [markdown]
# ## **Observations**
# The major factor affecting the Rental bikes demand are Temperature, Visibility, Rainfall and Snowfall. The rentals are independent of the wind speed and the humidity, because they are almost constant over the months.
#
# The rental bike is in most demand in the morning from 7 AM to 9 AM and in the evening from 5 PM to 8 PM. Hence, the Rental Bike companies need better planning for the availability of the rental bikes for this time period the most.
#
# The Rental Booking happens the most in summers specifically from May to July. Hence, the rental companies needs to plan the staffings required for the maintenance of bikes and smooth running of the business for this period the most.
#
# The Rental Bike demand is showing increasing trend. Hence, it is a booming business and there is a great scope of expansion.
#
# Linear regression, Lasso regression, Ridge regression, Decision Tree, Random Forest, AdaBoost, Gradient Boosting, Extreme Gradient Boosting Regressor, and XG Boost are just a few of the machine learning models we've employed. The accuracy of the Gradient Boosting Regressor and XG Boost is 89.2 percent and 89.1 percent, respectively. Hence, gradient boosting was used because it produces the most accurate results.

# %% [markdown]
# # **Conclusion**
# We have used many ML models such as Linear regression, Lasso Regression, Ridge Regression, Decision Tree, Random Forest, ADABoost, Gradient Boosting, Extreme Gradient Boosting Regressor and XG Boost. The Gradient Boosting Regressor and XG Boost are giving good accuracy with the accuracy being 89.2% and 89.1%. We have chosen Gradient boosting as Gradient Boosting is giving the most accurate results.
#
# As we can see the total amount of bike rentals increases with the temperature per month. Whereas it seems that the rentals are independent of the wind speed and the humidity, because they are almost constant over the months. This also confirms on the one hand the high correlation between rentals and temperature and on the other hand that nice weather could be a good predictor. So people mainly rent bikes on nice days and nice temperature. This could be important of planning new bike rental stations.
